# %%
import sys, os

sys.path.append('/cr/users/filip/bin')

from utils.binaries import *
from utils.plotting import *
# Out:
# 19:33:15 [INFO] utils.plotting -- ( +7525ms) -- import matplotlib.pyplot as plt
# 19:33:15 [INFO] utils.plotting -- (    +0ms) -- import matplotlib.pyplot as plt
# 19:33:15 [INFO] utils.plotting -- (    +0ms) -- import matplotlib.pyplot as plt
# 19:33:15 [INFO] utils.plotting -- (  +489ms) -- import seaborn as so
# 19:33:15 [INFO] utils.plotting -- (    +0ms) -- import seaborn as so
# 19:33:15 [DBUG] utils.plotting -- (    +7ms) -- font size set to 9.5
# 19:33:15 [DBUG] utils.plotting -- (    +0ms) -- font size set to 9.5
# 19:33:15 [DBUG] utils.plotting -- (    +1ms) -- label size set to 13.0
# 19:33:15 [DBUG] utils.plotting -- (    +0ms) -- label size set to 13.0
# 19:33:15 [DBUG] utils.plotting -- (    +1ms) -- figure size set to [6.6, 3.3]
# 19:33:15 [DBUG] utils.plotting -- (    +0ms) -- figure size set to [6.6, 3.3]
# 19:33:15 [DBUG] utils.plotting -- (    +1ms) -- markersize set to 2.0
# 19:33:15 [DBUG] utils.plotting -- (    +0ms) -- markersize set to 2.0
# ...

# %%
def do_random_walk():

# %%
from matplotlib.patches import Ellipse

galaxy = plt.imread('hubble.png')
height, width = galaxy.shape[:-1]

fig, (ax1, ax2) = plt.subplots(1, 2, width_ratios = [3, 2])

# x_scale_factor = 700 / 10  # px / kpc
# y_scale_factor = 250 / 1.5  # px / kpc

background = ax1.imshow(galaxy, extent=[-12, 12, -10 + 0.4, 10 + 0.4], alpha=0.9)
cr_halo = Ellipse((0, 0), 20, 12, color='w', alpha=0.1, label='CR Halo')

ax1.add_patch(cr_halo)
ax1.legend()

# %%
print(galaxy.shape[:-1])
# Out:
# (1014, 1898)

# %%
1014/1889
# Out:
# 0.536791953414505

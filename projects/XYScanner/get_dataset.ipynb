# %%
import sys
sys.path.append('/cr/users/filip/bin')

from utils.binaries import *
from utils.plotting import *
# Out:
# 17:49:11 [INFO] utils          -- ( +1375ms) -- import logging
# 17:49:11 [INFO] utils.binaries -- (  +178ms) -- import numpy as np
# 17:49:12 [INFO] utils.binaries -- (  +362ms) -- import pandas as pd
# 17:49:12 [INFO] utils.binaries -- (    +3ms) -- import binaries.tools as binaries
# 17:49:12 [INFO] utils.plotting -- (  +504ms) -- import matplotlib.pyplot as plt
# 17:49:13 [INFO] utils.plotting -- (  +403ms) -- import seaborn as sns
# 17:49:13 [DBUG] utils.plotting -- (   +14ms) -- font size set to 4
# 17:49:13 [DBUG] utils.plotting -- (    +1ms) -- figure size set to [2.4, 1.2]
# 17:49:13 [DBUG] utils.plotting -- (    +0ms) -- plotting style set to `notebook`.
# 17:49:13 [INFO] utils.plotting -- (    +3ms) -- import plotting.tools as plot

# %%
col_names = [
    "runid",
    "telescope",
    "stepsize_cm",
    "date",
    "source",
    "ledCurrent_mA",
    "forDB",
    "jobfile",
    "comment",
]

runlist_nov = pd.read_csv(
        '/cr/users/filip/projects/XYScanner/xy-calibration/config/calib_runlists/calib_runs_2023-11.list', sep=";", names=col_names, skipinitialspace=True, comment="#"
    )

runlist_nov
# Out:
#        runid telescope  stepsize_cm        date source  ledCurrent_mA  forDB  \
# 0   15918m23       co5            0  2023-11-07    NaN            0.0      0
# 1   15918m24       co6            0  2023-11-07    NaN            0.0      0
# 2      15919       co5            0  2023-11-07    NaN            0.0      0
# 3     15920x       co5            6  2023-11-07    OLO           15.9      1
# 4      15923       co5            0  2023-11-07    NaN            0.0      0
# ..       ...       ...          ...         ...    ...            ...    ...
# 75     15990       co5            0  2023-11-16    NaN            0.0      0
# 76      6100       he2            0  2023-11-16    NaN            0.0      0
# 77      6101       he2            6  2023-11-16    OLO           15.9      1
# 78      6102       he2            0  2023-11-16    NaN            0.0      0
# 79   6103m26       he2            0  2023-11-16    NaN            0.0      0
#
#                                   jobfile                      comment
# 0                                     NaN                        Cal A
# 1                                     NaN                        Cal A
# 2                                     NaN           Cal A open shutter
# 3                                     NaN                          NaN
# 4                                     NaN           Cal A open shutter
# ..                                    ...                          ...
# 75                                    NaN           Cal A open shutter
# 76                                    NaN           Cal A open shutter
# 77  job_HEAT_bay2_hex_s60_r0-1300_cut.txt  incomplete run, 1319 events
# 78                                    NaN           Cal A open shutter
# 79                                    NaN                        Cal A
#
# [80 rows x 9 columns]

# %%
for _id, row in runlist_nov.iterrows():
    if row.comment == "Cal A":
        runlist_nov.drop(_id, inplace=True)

runlist_nov
# Out:
#      runid telescope  stepsize_cm        date source  ledCurrent_mA  forDB  \
# 2    15919       co5            0  2023-11-07    NaN            0.0      0
# 3   15920x       co5            6  2023-11-07    OLO           15.9      1
# 4    15923       co5            0  2023-11-07    NaN            0.0      0
# 5    15924       co6            0  2023-11-07    NaN            0.0      0
# 6   15925x       co6            6  2023-11-07    OLO           15.9      1
# 7    15927       co6            0  2023-11-07    NaN            0.0      0
# 11   15930       co4            0  2023-11-08    NaN            0.0      0
# 12  15934x       co4            6  2023-11-08    OLO           15.9      1
# 13   15939       co4            0  2023-11-08    NaN            0.0      0
# 14   15940       co3            0  2023-11-08    NaN            0.0      0
# 15  15941x       co3            6  2023-11-08    OLO           15.9      1
# 16   15950       co3            0  2023-11-08    NaN            0.0      0
# 17   15951       co2            0  2023-11-08    NaN            0.0      0
# 18  15952x       co2            6  2023-11-08    OLO           15.9      1
# 19   15955       co2            0  2023-11-08    NaN            0.0      0
# 24   15958       co1            0  2023-11-09    NaN            0.0      0
# 25   15959       co1            6  2023-11-09    OLO           15.9      1
# 26   15960       co1            0  2023-11-09    NaN            0.0      0
# 27    6065       he3            0  2023-11-09    NaN            0.0      0
# 28    6066       he3            6  2023-11-09    OLO           15.9      1
# 29    6067       he3            0  2023-11-09    NaN            0.0      0
# 30    6068       he1            0  2023-11-09    NaN            0.0      0
# 31    6070       he1            6  2023-11-09    OLO           15.9      1
# 32    6071       he1            0  2023-11-09    NaN            0.0      0
# 36    6074       he2            0  2023-11-10    NaN            0.0      0
# 37    6075       he2            6  2023-11-10    OLO           15.9      1
# 38    6076       he2            0  2023-11-10    NaN            0.0      0
# 39   15966       co2            0  2023-11-11    NaN            0.0      0
# 40   15967       co2            6  2023-11-11    OLO           15.9      1
# 41   15968       co2            0  2023-11-11    NaN            0.0      0
# 45   12805       lm4            0  2023-11-13    NaN            0.0      0
# 46   12806       lm4            6  2023-11-13    OLO           15.9      1
# 47   12807       lm4            0  2023-11-13    NaN            0.0      0
# 48   12808       lm3            0  2023-11-13    NaN            0.0      0
# 49   12809       lm3            6  2023-11-13    OLO           15.9      1
# 50   12810       lm3            0  2023-11-13    NaN            0.0      0
# 51   12811       lm6            0  2023-11-13    NaN            0.0      0
# 52   12812       lm6            0  2023-11-13    NaN            0.0      0
# 60   12817       lm6            0  2023-11-14    NaN            0.0      0
# 61   12819       lm6            6  2023-11-14    OLO           15.9      1
# 62   12820       lm6            0  2023-11-14    NaN            0.0      0
# 63   12821       lm2            0  2023-11-14    NaN            0.0      0
# 64   12822       lm2            6  2023-11-14    OLO           15.9      1
# 65   12823       lm2            0  2023-11-14    NaN            0.0      0
# 66   12824       lm5            0  2023-11-14    NaN            0.0      0
# 67   12825       lm5            6  2023-11-14    OLO           15.9      1
# 68   12826       lm5            0  2023-11-14    NaN            0.0      0
# 69   12829       lm1            0  2023-11-14    NaN            0.0      0
# 70   12830       lm1            6  2023-11-14    OLO           15.9      1
# 71   12831       lm1            0  2023-11-14    NaN            0.0      0
# 73   15983       co5            0  2023-11-16    NaN            0.0      0
# 74  15984x       co5            6  2023-11-16    OLO           15.9      1
# 75   15990       co5            0  2023-11-16    NaN            0.0      0
# 76    6100       he2            0  2023-11-16    NaN            0.0      0
# 77    6101       he2            6  2023-11-16    OLO           15.9      1
# 78    6102       he2            0  2023-11-16    NaN            0.0      0
#
#                                               jobfile  \
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28              job_HEAT_bay3_hex_s60_r0-1300_cut.txt
# 29                                                NaN
# 30                                                NaN
# 31              job_HEAT_bay1_hex_s60_r0-1300_cut.txt
# 32                                                NaN
# 36                                                NaN
# 37                  job_HEAT_bay2_hex_s60_r0_1300_cut
# 38                                                NaN
# 39                                                NaN
# 40  job_Coihueco_bay2_hex_s60_r0-1300_cut.txt     ...
# 41                                                NaN
# 45                                                NaN
# 46            job_LosMorados_bay4_s60_r0-1250_cut.txt
# 47                                                NaN
# 48                                                NaN
# 49        job_LosMorados_bay3_hex_s60_r0-1250_cut.txt
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 60                                                NaN
# 61            job_LosMorados_bay6_s60_r0-1250_cut.txt
# 62                                                NaN
# 63                                                NaN
# 64        job_LosMorados_bay2_hex_s60_r0-1250_cut.txt
# 65                                                NaN
# 66                                                NaN
# 67        job_LosMorados_bay5_hex_s60_r0-1250_cut.txt
# 68                                                NaN
# 69                                                NaN
# 70        job_LosMorados_bay1_hex_s60_r0-1250_cut.txt
# 71                                                NaN
# 73                                                NaN
# 74          job_Coihueco_bay5_hex_s60_r0-1250_cut.txt
# 75                                                NaN
# 76                                                NaN
# 77              job_HEAT_bay2_hex_s60_r0-1300_cut.txt
# 78                                                NaN
#
#                         comment
# 2            Cal A open shutter
# 3                           NaN
# 4            Cal A open shutter
# 5            Cal A open shutter
# 6                           NaN
# 7            Cal A open shutter
# 11           Cal A open shutter
# 12                          NaN
# 13           Cal A open shutter
# 14           Cal A open shutter
# 15                          NaN
# 16           Cal A open shutter
# 17           Cal A open shutter
# 18                          NaN
# 19           Cal A open shutter
# 24           Cal A open shutter
# 25                          NaN
# 26           Cal A open shutter
# 27           Cal A open shutter
# 28                          NaN
# 29           Cal A open shutter
# 30           Cal A open shutter
# 31                          NaN
# 32           Cal A open shutter
# 36           Cal A open shutter
# 37                          NaN
# 38           Cal A open shutter
# 39           Cal A open shutter
# 40                          NaN
# 41           Cal A open shutter
# 45           Cal A open shutter
# 46                          NaN
# 47           Cal A open shutter
# 48           Cal A open shutter
# 49                          NaN
# 50           Cal A open shutter
# 51           Cal A open shutter
# 52           Cal A open shutter
# 60           Cal A open shutter
# 61                          NaN
# 62           Cal A open shutter
# 63           Cal A open shutter
# 64                          NaN
# 65           Cal A open shutter
# 66           Cal A open shutter
# 67                          NaN
# 68           Cal A open shutter
# 69           Cal A open shutter
# 70                          NaN
# 71           Cal A open shutter
# 73           Cal A open shutter
# 74                          NaN
# 75           Cal A open shutter
# 76           Cal A open shutter
# 77  incomplete run, 1319 events
# 78           Cal A open shutter

# %%
import glob
import os

for _id in runlist_nov['runid']:
    files = glob.glob(f'/cr/data02/AugerPrime/XY/2023nov_calA/*{_id}*')
    if files == []: continue
    os.remove(files[0])

# %% [markdown]
# ### remove run files as well...

# %%
import os
src = '/cr/data02/AugerPrime/XY/2023nov_calA/'

with open('/cr/users/filip/projects/XYScanner/xy-calibration/config/calib_runlists/calA_runs_2023-11.list', 'w') as runlist:
    for cal in os.listdir(src):
        fields = cal.split('_')
        print(fields)
        runlist.write(f'{fields[2][2:]}{fields[1]};  he{int(fields[1][1:]) - 24}; 0; {fields[3][:10]}; "";     0.0;   0;  "{fields[3][11:16]}";                                               "Cal A"\n')
# Out:
# ['Cal', 'Hw26-8332.ini']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 8
#       6 fields = cal.split('_')
#       7 print(fields)
# ----> 8 runlist.write(f'{fields[2][2:]}{fields[1]};  he{int(fields[1][1:]) - 24}; 0; {fields[3][:10]}; "";     0.0;   0;  "{fields[3][11:16]}";                                               "Cal A"\n')
#
# IndexError: list index out of range

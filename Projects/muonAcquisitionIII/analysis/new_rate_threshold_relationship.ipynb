# %%
from utils.binaries import *
from utils.plotting import *
from utils import CONSTANTS
# Out:
# 16:46:28 (   +1.2s) [INFO   ] -- import logging
# 16:46:28 (  +218ms) [INFO   ] -- import numpy as np
# 16:46:28 (   +13ms) [INFO   ] -- import uncertainties
# 16:46:29 (  +642ms) [INFO   ] -- import pandas as pd
# 16:46:29 (    +2ms) [WARNING] -- pandas support to be dropped at some point!
# 16:46:29 (    +2ms) [INFO   ] -- import binaries.tools as tools
# 16:46:29 (  +560ms) [INFO   ] -- import matplotlib.pyplot as plt
# 16:46:30 (  +809ms) [INFO   ] -- import seaborn as so
# 16:46:30 (    +3ms) [INFO   ] -- set MONI_PATH = PosixPath('/cr/work/filip/monit_and_sd')
# 16:46:30 (    +1ms) [INFO   ] -- set HIST_PATH = PosixPath('/cr/work/filip/monit_and_sd')
# 16:46:30 (    +1ms) [INFO   ] -- set PLOT_PATH = PosixPath('/cr/data01/filip/plots')
# 16:46:30 (    +1ms) [INFO   ] -- set DATA_PATH = PosixPath('/cr/data01/filip/Data')
# 16:46:30 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/cr/data01/filip/xy-calibration')
# ...

# %%
t3_mip = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionIII/mip_peak.pkl")
t, offsets, rates = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionIII/time_offset_rates.pkl")

# %%
for station, c, ls in zip([943, 944, 949, 954], ['k', 'r', 'b', 'c'], ['-', '--', '-.', ':']):
    # if station == 943: continue
    for o, r in zip(offsets[station], rates[station]):
        plt.plot((o + np.arange(len(r))) / t3_mip[station].n, r, 
                 marker='none', c=c, lw=0.3, alpha=0.5, ls=ls)

x, y = np.loadtxt('/cr/data01/filip/Data/muonAcquisition/mean_rates_t3_mip.txt', unpack=True)
plt.plot(x, y, label="old", lw=1, c='k', marker='none', ls='-')
# plt.fill_between(x, y*0.8, y*1.2,color='k', alpha=0.3, ec='none')

# plt.xlim(1.5, 5)
# plt.ylim(10, 180)
plt.yscale('log')
plt.legend()

# %%
print(t3_mip)
# Out:
# {}

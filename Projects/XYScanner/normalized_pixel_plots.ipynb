# %%
import sys, os

sys.path.append('/cr/users/filip/bin/')

from utils.binaries import *
from utils.plotting import *

from utils.Auger.FD import PixelPlot
# Out:
# 15:56:43 [INFO] utils          -- ( +2372ms) -- import logging
# 15:56:43 [INFO] utils.binaries -- (  +132ms) -- import numpy as np
# 15:56:43 [INFO] utils.binaries -- (    +6ms) -- import uncertainties
# 15:56:43 [INFO] utils.binaries -- (  +152ms) -- import pandas as pd
# 15:56:43 [INFO] utils.binaries -- (    +2ms) -- import binaries.tools as tools
# 15:56:44 [INFO] utils.plotting -- (  +465ms) -- import matplotlib.pyplot as plt
# 15:56:44 [INFO] utils.plotting -- (  +250ms) -- import seaborn as so
# 15:56:44 [DBUG] utils.plotting -- (    +7ms) -- font size set to 9.5
# 15:56:44 [DBUG] utils.plotting -- (    +1ms) -- label size set to 13.0
# 15:56:44 [DBUG] utils.plotting -- (    +0ms) -- figure size set to [6.6, 3.3]
# 15:56:44 [DBUG] utils.plotting -- (    +1ms) -- markersize set to 2.0
# 15:56:44 [DBUG] utils.plotting -- (    +1ms) -- usetex set to False
# 15:56:44 [INFO] utils.plotting -- (    +2ms) -- import plotting.tools as plot

# %%
import pickle

with open('/cr/users/filip/Projects/XYScanner/all_heat_measurements.pickle', 'rb') as f:
    XY_measurements = pickle.load(f)

# %%
for telescope, measurements in XY_measurements.items():
    
    print(telescope)

# %%
PixelPlot(np.arange(1, 441))

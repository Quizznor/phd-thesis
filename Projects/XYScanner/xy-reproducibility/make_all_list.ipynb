# %%
from utils.binaries import *
# Out:
# 07:29:52 (  +26.4s) [INFO   ] -- import logging
# 07:29:53 (  +148ms) [INFO   ] -- import numpy as np
# 07:29:53 (    +6ms) [INFO   ] -- import uncertainties
# 07:29:53 (  +444ms) [INFO   ] -- import pandas as pd
# 07:29:53 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 07:29:53 (    +1ms) [INFO   ] -- import binaries.tools as tools

# %%
runlist = pd.read_csv(
    f"/cr/data01/filip/xy-calibration/config/calib_runlists/calib_runs_2022-10.list",
    sep=";",
)
runlist["comment"] = [comment.strip() for comment in runlist["comment"]]
runlist["source"] = [source.strip() for source in runlist["source"]]

# add new runlists here!
for month in ["2023-10", "2023-11"]:
    this_runlist = pd.read_csv(
        f"/cr/data01/filip/xy-calibration/config/calib_runlists/calib_runs_{month}.list",
        sep=";",
    )
    this_runlist["comment"] = [comment.strip() for comment in this_runlist["comment"]]
    this_runlist["source"] = [source.strip() for source in this_runlist["source"]]

    runlist = pd.concat([runlist, this_runlist], ignore_index=True)

# %%
runlist
# Out:
#        #runid telescope  stepsize_cm            date source  ledCurrent_mA  \
# 0    15425m21       co3            0      2022-10-14     ""            0.0
# 1       15426       co3            0      2022-10-14     ""            0.0
# 2       15427       co3           16      2022-10-14  "KIT"            2.7
# 3       15428       co3            0      2022-10-14     ""            0.0
# 4       15430       co3            0      2022-10-14     ""            0.0
# ..        ...       ...          ...             ...    ...            ...
# 226    15984x       co5            6      2023-11-16  "OLO"           15.9
# 227     15990       co5            0      2023-11-16     ""            0.0
# 228      6100       he2            0      2023-11-16     ""            0.0
# 229      6102       he2            0      2023-11-16     ""            0.0
# 230   6103m26       he2            0      2023-11-16     ""            0.0
#
#      forDB                                            jobfile  \
# 0        0                                                 ""
# 1        0                                                 ""
# 2        0     "job_Coihueco_bay3-CZ_hex_s160_r0-1300_cut....
# 3        0                                                 ""
# 4        0                                                 ""
# ..     ...                                                ...
# 226      1        "job_Coihueco_bay5_hex_s60_r0-1250_cut.txt"
# 227      0                                                 ""
# 228      0                                                 ""
# 229      0                                                 ""
# 230      0                                                 ""
#
#                   comment
# 0                 "Cal A"
# 1    "Cal A open shutter"
# 2                      ""
# 3    "Cal A open shutter"
# 4    "Cal A open shutter"
# ..                    ...
# 226                    ""
# 227  "Cal A open shutter"
# 228  "Cal A open shutter"
# 229  "Cal A open shutter"
# 230               "Cal A"
#
# [231 rows x 9 columns]

# %%
only_xy_runs = runlist
only_xy_runs = runlist.drop(runlist[runlist["comment"] != '""'].index)
only_xy_runs = only_xy_runs.drop(only_xy_runs[only_xy_runs["source"] != '"OLO"'].index)
only_xy_runs = only_xy_runs.drop(only_xy_runs[only_xy_runs["forDB"] == 0].index)
only_xy_runs
# Out:
#      #runid telescope  stepsize_cm            date source  ledCurrent_mA  \
# 16   15443x       co5            6      2022-10-15  "OLO"           15.9
# 19    15448       co3            6      2022-10-15  "OLO"           15.9
# 22    15451       co4            6      2022-10-15  "OLO"           15.9
# 46   #11863       la3            6      2022-10-19  "OLO"           15.9
# 58    11875       la4            6      2022-10-20  "OLO"           15.9
# 66   05616x       he1            6      2022-10-21  "OLO"           15.9
# 69   05621x       he2            6      2022-10-21  "OLO"           15.9
# 72   05626x       he3            6      2022-10-21  "OLO"           15.9
# 95    15672       ll4            6      2022-10-24  "OLO"           15.9
# 98    15675       ll3            6      2022-10-24  "OLO"           15.9
# 110   6020x       he1            6      2023-10-13  "OLO"           15.9
# 113    6025       he2            6      2023-10-13  "OLO"           15.9
# 119   6031x       he3            6      2023-10-14  "OLO"           15.9
# 124  12275x       la3            6      2023-10-18  "OLO"           15.9
# 139  12301x       la4            6      2023-10-19  "OLO"           15.9
# 142  12307x       la5            6      2023-10-19  "OLO"           15.9
# 145  12320x       la6            6      2023-10-19  "OLO"           15.9
# 149  12328x       la1            6      2023-10-19  "OLO"           15.9
# 154  15920x       co5            6      2023-11-07  "OLO"           15.9
# 157  15925x       co6            6      2023-11-07  "OLO"           15.9
# 163  15934x       co4            6      2023-11-08  "OLO"           15.9
# 166  15941x       co3            6      2023-11-08  "OLO"           15.9
# 169  15952x       co2            6      2023-11-08  "OLO"           15.9
# 176   15959       co1            6      2023-11-09  "OLO"           15.9
# 181    6066       he3            6      2023-11-09  "OLO"           15.9
# 184    6070       he1            6      2023-11-09  "OLO"           15.9
# 190    6075       he2            6      2023-11-10  "OLO"           15.9
# 193   15967       co2            6      2023-11-11  "OLO"           15.9
# 199   12806       lm4            6      2023-11-13  "OLO"           15.9
# 202   12809       lm3            6      2023-11-13  "OLO"           15.9
# 216   12822       lm2            6      2023-11-14  "OLO"           15.9
# 219   12825       lm5            6      2023-11-14  "OLO"           15.9
# 222   12830       lm1            6      2023-11-14  "OLO"           15.9
# 226  15984x       co5            6      2023-11-16  "OLO"           15.9
#
#      forDB                                            jobfile comment
# 16       1     "job_Coihueco_bay5-CZ_hex_s60_r0-1300_cut.txt"      ""
# 19       1     "job_Coihueco_bay3-CZ_hex_s60_r0-1300_cut.txt"      ""
# 22       1     "job_Coihueco_bay4-CZ_hex_s60_r0-1300_cut.txt"      ""
# 46       1     "job_LomaAmarilla_bay3-CZ_hex_s60_r0-1300_c...      ""
# 58       1     "job_LomaAmarilla_bay4-CZ_hex_s60_r0-1300_c...      ""
# 66       1         "job_HEAT_bay1-CZ_hex_s60_r0-1300_cut.txt"      ""
# 69       1         "job_HEAT_bay2-CZ_hex_s60_r0-1300_cut.txt"      ""
# 72       1         "job_HEAT_bay3-CZ_hex_s60_r0-1300_cut.txt"      ""
# 95       1     "job_LosLeones_bay4-CZ_hex_s60_r0-1300_cut....      ""
# 98       1     "job_LosLeones_bay3-CZ_hex_s60_r0-1300_cut....      ""
# 110      1         "job_HEAT_bay1-CZ_hex_s60_r0-1300_cut.txt"      ""
# 113      1         "job_HEAT_bay2-CZ_hex_s60_r0-1300_cut.txt"      ""
# 119      1         "job_HEAT_bay3-CZ_hex_s60_r0-1300_cut.txt"      ""
# 124      1    "job_LomaAmarilla_bay3_hex_s60_r0-1250_cut.txt"      ""
# 139      1    "job_LomaAmarilla_bay4_hex_s60_r0-1250_cut.txt"      ""
# 142      1    "job_LomaAmarilla_bay5_hex_s60_r0-1250_cut.txt"      ""
# 145      1    "job_LomaAmarilla_bay6_hex_s60_r0-1250_cut.txt"      ""
# 149      1    "job_LomaAmarilla_bay1_hex_s60_r0-1250_cut.txt"      ""
# 154      1                                                 ""      ""
# 157      1                                                 ""      ""
# 163      1                                                 ""      ""
# 166      1                                                 ""      ""
# 169      1                                                 ""      ""
# 176      1                                                 ""      ""
# 181      1            "job_HEAT_bay3_hex_s60_r0-1300_cut.txt"      ""
# 184      1            "job_HEAT_bay1_hex_s60_r0-1300_cut.txt"      ""
# 190      1                "job_HEAT_bay2_hex_s60_r0_1300_cut"      ""
# 193      1        "job_Coihueco_bay2_hex_s60_r0-1300_cut.txt"      ""
# 199      1          "job_LosMorados_bay4_s60_r0-1250_cut.txt"      ""
# 202      1      "job_LosMorados_bay3_hex_s60_r0-1250_cut.txt"      ""
# 216      1      "job_LosMorados_bay2_hex_s60_r0-1250_cut.txt"      ""
# 219      1      "job_LosMorados_bay5_hex_s60_r0-1250_cut.txt"      ""
# 222      1      "job_LosMorados_bay1_hex_s60_r0-1250_cut.txt"      ""
# 226      1        "job_Coihueco_bay5_hex_s60_r0-1250_cut.txt"      ""

# %%
XY_measurements = {}

for index, measurement in only_xy_runs.iterrows():

    try:
        _ = XY_measurements[measurement["telescope"].strip()]
    except KeyError:
        XY_measurements[measurement["telescope"].strip()] = []

    (runid, telescope), date = measurement[:2], measurement["date"].strip()

    same_day = runlist[[d.strip() == date for d in runlist["date"]]]
    same_telescope = same_day[
        [t.strip() == telescope.strip() for t in same_day["telescope"]]
    ]

    year, month, day = date.split("-")

    XY_measurement = {
        "XY": measurement["#runid"],
        "CalA_closed_shutter": [None, None],
        "CalA_open_shutter": [None, None],
        "date": f"{year}-{month}-{day}",
    }

    # find Cal A closed shutter
    for candidate_index, candidate in same_telescope.iterrows():
        if candidate["comment"] == '"Cal A"':
            if candidate_index < index:
                XY_measurement["CalA_closed_shutter"][0] = candidate["#runid"]
            if candidate_index > index:
                XY_measurement["CalA_closed_shutter"][1] = candidate["#runid"]
        if candidate["comment"] == '"Cal A open shutter"':
            if candidate_index < index:
                XY_measurement["CalA_open_shutter"][0] = candidate["#runid"]
            if candidate_index > index:
                XY_measurement["CalA_open_shutter"][1] = candidate["#runid"]

    XY_measurements[telescope.strip()].append(XY_measurement)

# %%
XY_measurements
# Out:
# {'co5': [{'XY': '15443x',
#    'CalA_closed_shutter': ['15440m23', '15459m23'],
#    'CalA_open_shutter': ['15441', '15446'],
#    'date': '2022-10-15'},
#   {'XY': '15920x',
#    'CalA_closed_shutter': ['15918m23', None],
#    'CalA_open_shutter': ['15919', '15923'],
#    'date': '2023-11-07'},
#   {'XY': '15984x',
#    'CalA_closed_shutter': ['15982m23', None],
#    'CalA_open_shutter': ['15983', '15990'],
#    'date': '2023-11-16'}],
#  'co3': [{'XY': '15448',
#    'CalA_closed_shutter': ['15440m21', '15459m21'],
#    'CalA_open_shutter': ['15447', '15449'],
#    'date': '2022-10-15'},
#   {'XY': '15941x',
#    'CalA_closed_shutter': ['15929m21', '15956m21'],
#    'CalA_open_shutter': ['15940', '15950'],
#    'date': '2023-11-08'}],
#  'co4': [{'XY': '15451',
#    'CalA_closed_shutter': ['15440m22', '15459m22'],
#    'CalA_open_shutter': ['15450', '15458'],
#    'date': '2022-10-15'},
#   {'XY': '15934x',
#    'CalA_closed_shutter': ['15929m22', '15956m22'],
#    'CalA_open_shutter': ['15930', '15939'],
#    'date': '2023-11-08'}],
#  'la3': [{'XY': '#11863',
#    'CalA_closed_shutter': ['11861m16', None],
#    'CalA_open_shutter': ['11862', None],
#    'date': '2022-10-19'},
#   {'XY': '12275x',
#    'CalA_closed_shutter': ['12273m15', None],
#    'CalA_open_shutter': ['12274', '12288'],
#    'date': '2023-10-18'}],
#  'la4': [{'XY': '11875',
#    'CalA_closed_shutter': ['11865m16', '11877m16'],
#    'CalA_open_shutter': ['11874', '11876'],
#    'date': '2022-10-20'},
#   {'XY': '12301x',
#    'CalA_closed_shutter': ['12298m16', None],
#    'CalA_open_shutter': ['12299', '12305'],
#    'date': '2023-10-19'}],
#  'he1': [{'XY': '05616x',
#    'CalA_closed_shutter': ['05613m25', '05629m25'],
#    'CalA_open_shutter': ['05614', '05619'],
#    'date': '2022-10-21'},
#   {'XY': '6020x',
#    'CalA_closed_shutter': ['6018m25', None],
#    'CalA_open_shutter': ['6019', '6023'],
#    'date': '2023-10-13'},
#   {'XY': '6070',
#    'CalA_closed_shutter': ['6062m25', '6072m25'],
#    'CalA_open_shutter': ['6068', '6071'],
#    'date': '2023-11-09'}],
#  'he2': [{'XY': '05621x',
#    'CalA_closed_shutter': ['05613m26', '05629m26'],
#    'CalA_open_shutter': ['05620', '05624'],
#    'date': '2022-10-21'},
#   {'XY': '6025',
#    'CalA_closed_shutter': ['6018m26', None],
#    'CalA_open_shutter': ['6024', '6026'],
#    'date': '2023-10-13'},
#   {'XY': '6075',
#    'CalA_closed_shutter': ['6073m26', None],
#    'CalA_open_shutter': ['6074', '6076'],
#    'date': '2023-11-10'}],
#  'he3': [{'XY': '05626x',
#    'CalA_closed_shutter': ['05613m27', '05629m27'],
#    'CalA_open_shutter': ['05625', '05628'],
#    'date': '2022-10-21'},
#   {'XY': '6031x',
#    'CalA_closed_shutter': ['6029m27', None],
#    'CalA_open_shutter': ['6030', '6035'],
#    'date': '2023-10-14'},
#   {'XY': '6066',
#    'CalA_closed_shutter': ['6062m27', '6072m27'],
#    'CalA_open_shutter': ['6065', '6067'],
#    'date': '2023-11-09'}],
#  'll4': [{'XY': '15672',
#    'CalA_closed_shutter': ['15668m04', '15681m04'],
#    'CalA_open_shutter': ['15671', '15673'],
#    'date': '2022-10-24'}],
#  'll3': [{'XY': '15675',
#    'CalA_closed_shutter': ['15668m03', '15681m03'],
#    'CalA_open_shutter': ['15674', '15680'],
#    'date': '2022-10-24'}],
#  'la5': [{'XY': '12307x',
#    'CalA_closed_shutter': ['12298m17', None],
#    'CalA_open_shutter': ['12306', '12318'],
#    'date': '2023-10-19'}],
#  'la6': [{'XY': '12320x',
#    'CalA_closed_shutter': ['12298m18', None],
#    'CalA_open_shutter': ['12319', '12323'],
#    'date': '2023-10-19'}],
#  'la1': [{'XY': '12328x',
#    'CalA_closed_shutter': ['12298m13', None],
#    'CalA_open_shutter': ['12327', '12334'],
#    'date': '2023-10-19'}],
#  'co6': [{'XY': '15925x',
#    'CalA_closed_shutter': ['15918m24', None],
#    'CalA_open_shutter': ['15924', '15927'],
#    'date': '2023-11-07'}],
#  'co2': [{'XY': '15952x',
#    'CalA_closed_shutter': [None, None],
#    'CalA_open_shutter': ['15951', '15955'],
#    'date': '2023-11-08'},
#   {'XY': '15967',
#    'CalA_closed_shutter': [None, None],
#    'CalA_open_shutter': ['15966', '15968'],
#    'date': '2023-11-11'}],
#  'co1': [{'XY': '15959',
#    'CalA_closed_shutter': ['15957m19', None],
#    'CalA_open_shutter': ['15958', '15960'],
#    'date': '2023-11-09'}],
#  'lm4': [{'XY': '12806',
#    'CalA_closed_shutter': ['12804m10', '12813m10'],
#    'CalA_open_shutter': ['12805', '12807'],
#    'date': '2023-11-13'}],
#  'lm3': [{'XY': '12809',
#    'CalA_closed_shutter': ['12804m9', '12813m9'],
#    'CalA_open_shutter': ['12808', '12810'],
#    'date': '2023-11-13'}],
#  'lm2': [{'XY': '12822',
#    'CalA_closed_shutter': ['12816m08', None],
#    'CalA_open_shutter': ['12821', '12823'],
#    'date': '2023-11-14'}],
#  'lm5': [{'XY': '12825',
#    'CalA_closed_shutter': ['12816m11', None],
#    'CalA_open_shutter': ['12824', '12826'],
#    'date': '2023-11-14'}],
#  'lm1': [{'XY': '12830',
#    'CalA_closed_shutter': ['12816m07', None],
#    'CalA_open_shutter': ['12829', '12831'],
#    'date': '2023-11-14'}]}

# %%
import pickle

# save events to disk
with open("/cr/users/filip/bin/utils/Auger/FD/xy_measurements.pkl", "wb") as f:
    pickle.dump(XY_measurements, f, pickle.HIGHEST_PROTOCOL)

# %%
from utils.Auger.FD import XYscanner
# Out:
# 20:11:58 (   +1.8s) [INFO   ] -- import logging
# 20:11:59 (  +397ms) [INFO   ] -- import matplotlib.pyplot as plt
# 20:11:59 (  +599ms) [INFO   ] -- import seaborn as so
# 20:11:59 (    +7ms) [DEBUG  ] -- font size set to 9.5
# 20:11:59 (    +0ms) [DEBUG  ] -- label size set to 13.0
# 20:11:59 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 20:11:59 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 20:11:59 (    +1ms) [DEBUG  ] -- usetex set to False
# 20:11:59 (    +2ms) [INFO   ] -- import numpy as np
# 20:11:59 (    +7ms) [INFO   ] -- import uncertainties
# 20:11:59 (    +1ms) [INFO   ] -- import pandas as pd
# 20:11:59 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 20:11:59 (    +2ms) [INFO   ] -- import binaries.tools as tools
# 20:11:59 (    +1ms) [INFO   ] -- import plotting.tools as plot

# %%
print(XYscanner.get_run_numbers("co3", "2023nov"))
# Out:
# {'XY': '15941x', 'CalA_closed_shutter': ['15929m21', '15956m21'], 'CalA_open_shutter': ['15940', '15950'], 'date': '2023nov'}

# %%
import pickle

with open("/cr/users/filip/bin/utils/Auger/FD/xy_measurements.pkl", "rb") as f:
    data = pickle.load(f)


print(data["co3"])
# Out:
# [{'XY': '15448', 'CalA_closed_shutter': ['15440m21', '15459m21'], 'CalA_open_shutter': ['15447', '15449'], 'date': '2022oct'}, {'XY': '15941x', 'CalA_closed_shutter': ['15929m21', '15956m21'], 'CalA_open_shutter': ['15940', '15950'], 'date': '2023nov'}]

# %%
for measurement in data["co3"]:
    print(measurement)
# Out:
# {'XY': '15448', 'CalA_closed_shutter': ['15440m21', '15459m21'], 'CalA_open_shutter': ['15447', '15449'], 'date': '2022oct'}
# {'XY': '15941x', 'CalA_closed_shutter': ['15929m21', '15956m21'], 'CalA_open_shutter': ['15940', '15950'], 'date': '2023nov'}

# %%
from utils.binaries import *
from utils.plotting import *
from utils.Auger.FD import XYScanner

# %%
results_dir = "/cr/data01/filip/xy-calibration/results/"

# %%
pix, calibConst, adcSum, stdConst, calibConstCorr = np.loadtxt(
    results_dir + "outCorr_12809.txt", unpack=True
)

# %%
plt.scatter(pix, calibConst, label="XY")
plt.scatter(pix, stdConst, label="Std")
plt.scatter(pix, calibConstCorr, label="XyCorr")

plt.legend()

# %%
import sys, os

sys.path.append('/cr/users/filip/bin')

from utils.binaries import *
from utils.plotting import *
# Out:
# 10:06:03 [INFO] utils          -- (  +841ms) -- import logging
# 10:06:03 [INFO] utils.binaries -- (  +118ms) -- import numpy as np
# 10:06:03 [INFO] utils.binaries -- (   +15ms) -- import uncertainties
# 10:06:03 [INFO] utils.binaries -- (  +218ms) -- import pandas as pd
# 10:06:03 [INFO] utils.binaries -- (    +2ms) -- import binaries.tools as tools
# 10:06:04 [INFO] utils.plotting -- (  +364ms) -- import matplotlib.pyplot as plt
# 10:06:04 [INFO] utils.plotting -- (  +656ms) -- import seaborn as so
# 10:06:04 [DBUG] utils.plotting -- (   +14ms) -- font size set to 9.5
# 10:06:04 [DBUG] utils.plotting -- (    +1ms) -- label size set to 13.0
# 10:06:04 [DBUG] utils.plotting -- (    +1ms) -- figure size set to [6.6, 3.3]
# 10:06:04 [DBUG] utils.plotting -- (    +1ms) -- markersize set to 2.0
# 10:06:04 [DBUG] utils.plotting -- (    +2ms) -- usetex set to False
# 10:06:04 [INFO] utils.plotting -- (    +1ms) -- import plotting.tools as plot

# %%
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(6.6, 6.6))
gs = GridSpec(4, 4)
gs.update(wspace=0, hspace=0)

for i in range(16):
    ax1 = plt.subplot(gs[i])
    
    plt.axis('on')
    ax1.set_xticklabels([])
    ax1.set_yticklabels([])
    ax1.set_aspect('equal')


# for r, row in enumerate(axes):
#     for c, ax in enumerate(row):
#         ax.set_aspect('equal')

#         if r == 0 and c in [1, 2, 3]: ax.axis('off')
#         if r == 1 and c in [2, 3]: ax.axis('off')
#         if r == 2 and c in [3]: ax.axis('off')

# axes[0,0].set_ylabel('Nuria Jr'), axes[3, 0].set_xlabel('Nuria Jr')
# axes[1,0].set_ylabel('Constanza'), axes[3, 1].set_xlabel('Constanza')
# axes[2,0].set_ylabel('Svenja'), axes[3, 2].set_xlabel('Svenja')
# axes[3,0].set_ylabel('Nadia'), axes[3, 3].set_xlabel('Nadia')
# axes[0,0].set_xscale('log')
# plt.subplots_adjust(hspace = 0, wspace = 0)

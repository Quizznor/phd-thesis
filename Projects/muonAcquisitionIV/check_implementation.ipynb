# %%
from utils.binaries import *
from utils.plotting import *
from utils.auger.sd.histo import *
# Out:
# 22:53:21 (   +1.3s) [INFO   ] -- import logging
# 22:53:21 (   +77ms) [INFO   ] -- import numpy as np
# 22:53:21 (    +6ms) [INFO   ] -- import uncertainties
# 22:53:22 (  +157ms) [INFO   ] -- import pandas as pd
# 22:53:22 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 22:53:22 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 22:53:22 (  +229ms) [INFO   ] -- import matplotlib.pyplot as plt
# 22:53:22 (  +288ms) [INFO   ] -- import seaborn as so
# 22:53:22 (    +1ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 22:53:22 (    +1ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 22:53:22 (    +0ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 22:53:22 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 22:53:22 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# ...

# %%
histos = read_histos('peak.txt')

# %%
for hist in histos[::-1]:
    if hist['id'] == 136: break

h = SdHisto(peak=hist['data'], pmt_mask=[0,0,0,1])
fig = h.plot()
fig.suptitle(f"{plot.to_datetime(hist['timestamp'])} - {hist['id']}")
plt.yscale('log')

# %%
plt.plot(range(150), h[2], marker='none')
plt.plot(range(150), h[3], marker='none')

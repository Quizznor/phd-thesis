# %%
from utils.binaries import *
from utils.plotting import *
from utils.auger.sd.histo import *
# Out:
# 02:37:01 (   +1.6s) [INFO   ] -- import logging
# 02:37:01 (   +71ms) [INFO   ] -- import numpy as np
# 02:37:01 (    +6ms) [INFO   ] -- import uncertainties
# 02:37:01 (  +156ms) [INFO   ] -- import pandas as pd
# 02:37:01 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 02:37:01 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 02:37:02 (  +240ms) [INFO   ] -- import matplotlib.pyplot as plt
# 02:37:02 (  +278ms) [INFO   ] -- import seaborn as so
# 02:37:02 (    +2ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 02:37:02 (    +0ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 02:37:02 (    +1ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 02:37:02 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 02:37:02 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# 02:37:02 (    +1ms) [INFO   ] -- set OFLN_PATH = PosixPath('/home/filip/Public/offline/install')
# 02:37:02 (    +0ms) [INFO   ] -- import plotting.tools as plot
# 02:37:02 (    +5ms) [DEBUG  ] -- font size set to 9.5
# 02:37:02 (    +0ms) [DEBUG  ] -- label size set to 13.0
# 02:37:02 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 02:37:02 (    +0ms) [DEBUG  ] -- markersize set to 2.0
# 02:37:02 (    +1ms) [DEBUG  ] -- usetex set to False

# %%
histos = read_histos('peak.txt')

# %%
for hist in histos[::-1]:
    if hist['id'] == 136: break

h = SdHisto(peak=hist['data'], pmt_mask=[0,0,0,1])
fig = h.plot()
fig.suptitle(f"{plot.to_datetime(hist['timestamp'])} - {hist['id']}")
# Out:
# Text(0.5, 0.98, '2025-02-26 02:33:43 - 136')

# %%
from utils.binaries import *
from utils.plotting import *
from utils import CONSTANTS
# Out:
# 17:02:25 ( +105.7s) [INFO   ] -- import logging
# 17:02:26 (  +205ms) [INFO   ] -- import numpy as np
# 17:02:26 (   +12ms) [INFO   ] -- import uncertainties
# 17:02:26 (  +419ms) [INFO   ] -- import pandas as pd
# 17:02:26 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 17:02:26 (    +3ms) [INFO   ] -- import binaries.tools as tools
# 17:02:27 (  +431ms) [INFO   ] -- import matplotlib.pyplot as plt
# 17:02:27 (  +638ms) [INFO   ] -- import seaborn as so
# 17:02:27 (    +4ms) [INFO   ] -- set MONI_PATH = PosixPath('/cr/work/filip/monit_and_sd')
# 17:02:27 (    +1ms) [INFO   ] -- set HIST_PATH = PosixPath('/cr/work/filip/monit_and_sd')
# 17:02:27 (    +0ms) [INFO   ] -- set PLOT_PATH = PosixPath('/cr/data01/filip/plots')
# 17:02:27 (    +1ms) [INFO   ] -- set DATA_PATH = PosixPath('/cr/data01/filip/Data')
# 17:02:27 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/cr/data01/filip/xy-calibration')
# 17:02:27 (    +1ms) [INFO   ] -- set OFLN_PATH = PosixPath('/cr/data01/filip/offline/install')
# 17:02:27 (    +1ms) [INFO   ] -- import plotting.tools as plot
# 17:02:27 (   +17ms) [DEBUG  ] -- font size set to 9.5
# 17:02:27 (    +0ms) [DEBUG  ] -- label size set to 13.0
# 17:02:27 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 17:02:27 (    +0ms) [DEBUG  ] -- markersize set to 2.0
# 17:02:27 (    +1ms) [DEBUG  ] -- usetex set to False

# %%
t3_mip = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionII/mip_peak.pkl")
t, offsets, rates = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionII/time_offset_rates.pkl")

# %%
for station, c in zip([943, 944, 949, 954], ['k', 'r', 'b', 'c']):
    for o, r in zip(offsets[station], rates[station]):
        plt.plot((o + np.arange(len(r))) / t3_mip[station].n, r, 
                 marker='none', c=c, lw=0.3, alpha=0.5)

x, y = np.loadtxt('/cr/data01/filip/Data/muonAcquisition/mean_rates_t3_mip.txt', unpack=True)
plt.plot(x, y, label="old", lw=1, c='k', marker='none', ls='-')
plt.fill_between(x, y*0.8, y*1.2,color='k', alpha=0.3, ec='none')

plt.xlim(1.5, 5)
plt.ylim(10, 180)
plt.yscale('log')
plt.legend()

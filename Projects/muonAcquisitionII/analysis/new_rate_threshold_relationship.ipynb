# %%
from utils.binaries import *
from utils.plotting import *
from utils import CONSTANTS
# Out:
# 15:25:51 (+13659.0s) [INFO   ] -- import logging
# 15:25:51 (  +236ms) [INFO   ] -- import numpy as np
# 15:25:51 (   +12ms) [INFO   ] -- import uncertainties
# 15:25:52 (  +514ms) [INFO   ] -- import pandas as pd
# 15:25:52 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 15:25:52 (    +2ms) [INFO   ] -- import binaries.tools as tools
# 15:25:53 (  +765ms) [INFO   ] -- import matplotlib.pyplot as plt
# 15:25:54 (   +1.4s) [INFO   ] -- import seaborn as so
# 15:25:54 (    +4ms) [INFO   ] -- import plotting.tools as plot
# 15:25:54 (   +23ms) [DEBUG  ] -- font size set to 9.5
# 15:25:54 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 15:25:54 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 15:25:54 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 15:25:54 (    +1ms) [DEBUG  ] -- usetex set to False
# 15:25:54 (    +3ms) [INFO   ] -- set MONI_PATH = '/cr/work/filip/monit_and_sd/'
# 15:25:54 (    +1ms) [INFO   ] -- set HIST_PATH = '/cr/work/filip/monit_and_sd/'
# 15:25:54 (   +10ms) [INFO   ] -- set PLOT_PATH = '/cr/data01/filip/plots/'
# 15:25:54 (    +1ms) [INFO   ] -- set DATA_PATH = '/cr/data01/filip/Data/'

# %%
t3_mip = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionII/mip_peak.pkl")
t, offsets, rates = tools.pickle_load(f"{CONSTANTS.DATA_PATH}/muonAcquisitionII/time_offset_rates.pkl")

# %%
for station, c in zip([943, 944, 949, 954], ['k', 'r', 'b', 'c']):
    for o, r in zip(offsets[station], rates[station]):
        plt.plot((o + np.arange(len(r))) / t3_mip[station].n, r, 
                 marker='none', c=c, lw=0.3, alpha=0.5)

x, y = np.loadtxt('/cr/data01/filip/Data/muonAcquisition/mean_rates_t3_mip.txt', unpack=True)
plt.plot(x, y, label="old", lw=1, c='k', marker='none', ls='-')
plt.fill_between(x, y*0.8, y*1.2,color='k', alpha=0.3, ec='none')

# plt.xlim(1.5, 5)
# plt.ylim(10, 180)
plt.yscale('log')
plt.legend()

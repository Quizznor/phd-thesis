# %%
from utils.binaries import *
from utils.plotting import *

process = lambda x: [float(_) for _ in x[7::9]]
perf_new = process(
    np.loadtxt(
        "/cr/data01/filip/Data/daqIntegrationTests/performance/perf_new_version.out",
        dtype=str,
    )
)
perf_old = process(
    np.loadtxt(
        "/cr/data01/filip/Data/daqIntegrationTests/performance/perf_old_version.out",
        dtype=str,
    )
)

# %%
plt.plot(range(200), perf_new, label="ssd online calib")
plt.plot(range(200), perf_old, label="v128r0b0p29")
plt.xlabel("it / s")
plt.ylabel("cpu usage / %")
plt.legend()

# %%
from utils.binaries import *
from utils.plotting import *

pid, old = np.loadtxt(
    "/cr/data01/filip/Data/daqIntegrationTests/performance/v43_2/old.txt",
    usecols=[0, 7],
    unpack=True,
)
old = old[pid == 4543]
# old = old[7:]

pid, new = np.loadtxt(
    "/cr/data01/filip/Data/daqIntegrationTests/performance/v43_2/new.txt",
    usecols=[0, 7],
    unpack=True,
)
new = new[pid == 3299]
# new = new[12:]
# Out:
# 18:21:34 (  +28.2s) [INFO   ] -- import logging
# 18:21:34 (    +1ms) [INFO   ] -- import numpy as np
# 18:21:35 (    +7ms) [INFO   ] -- import uncertainties
# 18:21:34 (    +1ms) [INFO   ] -- import numpy as np
# 18:21:35 (    +7ms) [INFO   ] -- import uncertainties
# 18:21:35 (  +207ms) [INFO   ] -- import pandas as pd
# 18:21:35 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 18:21:35 (    +2ms) [INFO   ] -- import binaries.tools as tools
# 18:21:35 (  +302ms) [INFO   ] -- import matplotlib.pyplot as plt
# 18:21:35 (  +414ms) [INFO   ] -- import seaborn as so
# 18:21:35 (    +2ms) [INFO   ] -- import plotting.tools as plot
# 18:21:35 (    +7ms) [DEBUG  ] -- font size set to 9.5
# 18:21:35 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 18:21:35 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 18:21:35 (    +0ms) [DEBUG  ] -- markersize set to 2.0
# 18:21:35 (    +1ms) [DEBUG  ] -- usetex set to False

# %%
set_plt_style("double")

plt.hist(
    old,
    histtype="step",
    bins=20,
    label=rf"v128r0b0p29,      $\mu\,=\,{np.mean(old):.2f}$%, $\sigma\,=\,{np.std(old):.2f}$%",
    density=True,
)
plt.hist(
    new,
    histtype="step",
    bins=20,
    label=rf"SSD online calib, $\mu\,=\,{np.mean(new):.2f}$%, $\sigma\,=\,{np.std(new):.2f}$%",
    density=True,
)

plt.xlabel("CPU usage / %")
plt.yticks([])

plt.legend(fontsize=7)
plt.ylim(0, 0.45)
# Out:
# 18:22:12 (   +7.7s) [DEBUG  ] -- font size set to 9.5
# 18:22:12 (    +2ms) [DEBUG  ] -- label size set to 13.0
# 18:22:12 (    +2ms) [DEBUG  ] -- figure size set to [3.3, 2.5]
# 18:22:12 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 18:22:12 (    +1ms) [DEBUG  ] -- usetex set to False
# (0.0, 0.45)

# %%
from utils.binaries import *
from utils.plotting import *
# Out:
# 14:38:35 (+9710.7s) [INFO   ] -- import logging
# 14:38:35 (    +2ms) [INFO   ] -- import numpy as np
# 14:38:35 (    +7ms) [INFO   ] -- import uncertainties
# 14:38:35 (    +2ms) [INFO   ] -- import numpy as np
# 14:38:35 (    +7ms) [INFO   ] -- import uncertainties
# 14:38:35 (  +234ms) [INFO   ] -- import pandas as pd
# 14:38:35 (    +2ms) [WARNING] -- pandas support to be dropped at some point!
# 14:38:35 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 14:38:36 (  +312ms) [INFO   ] -- import matplotlib.pyplot as plt
# 14:38:36 (  +469ms) [INFO   ] -- import seaborn as so
# 14:38:36 (    +2ms) [INFO   ] -- import plotting.tools as plot
# 14:38:36 (    +7ms) [DEBUG  ] -- font size set to 9.5
# 14:38:36 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 14:38:36 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 14:38:36 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 14:38:36 (    +1ms) [DEBUG  ] -- usetex set to False

# %%
t, wcd1, hz1, wcd2, hz2, wcd3, hz3, ssd, hz4 = np.loadtxt('/cr/data01/filip/Data/daqIntegrationTests/v23/calib.test', unpack=True)
nan_mask = np.isnan(t)

t[nan_mask] = np.interp(np.flatnonzero(nan_mask), np.flatnonzero(~nan_mask), t[~nan_mask])
muonfill = lambda x: x[~nan_mask]
xb = lambda x: x[nan_mask]

ssd /= 100
wcd1[~nan_mask] /= 100
wcd2[~nan_mask] /= 100
wcd3[~nan_mask] /= 100
t = (t - t[0]) / 3600

start, stop, skip = 0, -1, 1

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
# ax1.plot(xb(t)[start:stop:skip], xb(wcd1)[start:stop:skip], label="WCD 1", ls='--', c='r')
# ax1.plot(xb(t)[start:stop:skip], xb(wcd2)[start:stop:skip], label="WCD 2", ls='--', c='b')
# ax1.plot(xb(t)[start:stop:skip], xb(wcd3)[start:stop:skip], label="WCD 3", ls='--', c='mediumturquoise')

ax1.plot(muonfill(t)[start:stop:skip], muonfill(wcd1)[start:stop:skip], ls='solid', c='r', label='WCD 1')
ax1.plot(muonfill(t)[start:stop:skip], muonfill(wcd2)[start:stop:skip], ls='solid', c='b', label='WCD 2')
ax1.plot(muonfill(t)[start:stop:skip], muonfill(wcd3)[start:stop:skip], ls='solid', c='mediumturquoise', label='WCD 3')
ax1.plot(muonfill(t)[start:stop:skip], muonfill(ssd)[start:stop:skip], label=r"10$\,\times\,$SSD", c='k')

ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz1)[start:stop:skip], c='r')
ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz2)[start:stop:skip], c='b')
ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz3)[start:stop:skip], c='mediumturquoise')
ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz4)[start:stop:skip], c='k')

ax2.axhline(70, ls='--', lw=0.8, c='gray') 
ax1.legend(bbox_to_anchor=(0, 1.02,1,0.2), loc="lower left", ncol=4)
ax1.set_ylabel("$I_\mathrm{Rate}\,/\,\mathrm{ADC}$")
ax2.set_ylabel("$\mathrm{T}70\,/\,\mathrm{Hz}$")
ax2.set_xlabel("time after DAQ start / h")
# ax2.set_ylim(30, 180)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t, wcd1, hz1, wcd2, hz2, wcd3, hz3, ssd, hz4 = np.loadtxt('/cr/data01/filip/Data/daqIntegrationTests/v23/calib.test', unpack=True)
#       2 nan_mask = np.isnan(t)
#       4 t[nan_mask] = np.interp(np.flatnonzero(nan_mask), np.flatnonzero(~nan_mask), t[~nan_mask])
#
# File ~/.venv/lib/python3.10/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/.venv/lib/python3.10/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/.venv/lib/python3.10/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/.venv/lib/python3.10/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /cr/data01/filip/Data/daqIntegrationTests/v23/calib.test not found.

# %%
_ = plt.hist(muonfill(hz1), range=(40, 100), bins=30, histtype='step', color='r', label=fr'WCD 1')
_ = plt.hist(muonfill(hz2), range=(40, 100), bins=30, histtype='step', color='b', label='WCD 2')
_ = plt.hist(muonfill(hz3), range=(40, 100), bins=30, histtype='step', color='mediumturquoise', label='WCD 3')
_ = plt.hist(muonfill(hz4), range=(40, 100), bins=30, histtype='step', color='k', label='SSD')

plt.legend()
plt.ylabel('# of occurrences')
plt.xlabel('T70 / Hz')
# Out:
# Text(0.5, 0, 'T70 / Hz')

# %%
r1 = xb(wcd1)[::9] / muonfill(wcd1)[::10]
r2 = xb(wcd2)[::9] / muonfill(wcd2)[::10]
r3 = xb(wcd3)[::9] / muonfill(wcd3)[::10]

plt.scatter(xb(t)[::9], r1, c='r')
plt.scatter(xb(t)[::9], r2, c='b')
plt.scatter(muonfill(t)[::10], r3, c='mediumturquoise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 r1 = xb(wcd1)[::9] / muonfill(wcd1)[::10]
#       2 r2 = xb(wcd2)[::9] / muonfill(wcd2)[::10]
#       3 r3 = xb(wcd3)[::9] / muonfill(wcd3)[::10]
#
# ValueError: operands could not be broadcast together with shapes (150,) (170,)

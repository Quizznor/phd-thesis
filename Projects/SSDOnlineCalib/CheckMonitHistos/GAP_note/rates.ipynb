# %%
import sys, os
sys.path.append('/cr/users/filip/bin/')

# from utils.Auger.SD import Monitoring

from utils.binaries import *
from utils.plotting import *
# Out:
# 12:42:47 [INFO] utils          -- (<99999ms) -- import logging
# 12:42:47 [INFO] utils.binaries -- (   +81ms) -- import numpy as np
# 12:42:47 [INFO] utils.binaries -- (   +11ms) -- import uncertainties
# 12:42:47 [INFO] utils.binaries -- (  +179ms) -- import pandas as pd
# 12:42:47 [INFO] utils.binaries -- (    +2ms) -- import binaries.tools as tools
# 12:42:48 [INFO] utils.plotting -- (  +454ms) -- import matplotlib.pyplot as plt
# 12:42:48 [INFO] utils.plotting -- (  +319ms) -- import seaborn as so
# 12:42:48 [DBUG] utils.plotting -- (    +6ms) -- font size set to 9.5
# 12:42:48 [DBUG] utils.plotting -- (    +2ms) -- label size set to 13.0
# 12:42:48 [DBUG] utils.plotting -- (    +0ms) -- figure size set to [6.6, 3.3]
# 12:42:48 [DBUG] utils.plotting -- (    +1ms) -- markersize set to 2.0
# 12:42:48 [DBUG] utils.plotting -- (    +1ms) -- usetex set to False
# 12:42:48 [INFO] utils.plotting -- (    +2ms) -- import plotting.tools as plot

# %%
thresholds = np.round(np.arange(1.0, 5.01, 0.05), 2)
data = pd.read_csv('/cr/tempdata01/filip/SSDCalib/BootstrapHistos/rates.txt', sep=' ', index_col=False)

data = data.dropna()
# data = data.drop(data[data['#id'] == 734].index)
# data = data.drop(data[data['#id'] == 1732].index)

# in UUB RANDOMS STATIONS FROM {Dec, Mar, Jun, Sep} 2021-2023
# 29681 events in dataset before fitting algorithm rework
# 44958 events in dataset AFTER fitting algoritm reworked

# in ALL STATIONS in {Jun, Dec} 2023
# 869_609 showers

# %%
from scipy.stats import zscore

# remove station specific outliers (3 sigma)
data_wo_outliers = pd.DataFrame([], columns=data.columns)
for station in np.unique(data['#id']):
    mask = data['#id'] == station
    df = data[mask]
    n_orig = len(df)

    for col in df.columns:
        if not col.endswith('xmip'): continue
        df = df.drop(df[np.abs(zscore(df[col])) > 3].index)
    
    n_wo_outlier = len(df)
    data_wo_outliers = pd.concat([data_wo_outliers, df])

    print(f"{n_orig - n_wo_outlier} outliers removed for station {station}...")
# Out:
# 91 outliers removed for station 56...
# 93 outliers removed for station 101...
# 5 outliers removed for station 102...
# 38 outliers removed for station 103...
# 71 outliers removed for station 104...
# 64 outliers removed for station 105...
# 39 outliers removed for station 106...
# 26 outliers removed for station 107...
# 80 outliers removed for station 108...
# 63 outliers removed for station 109...
# 97 outliers removed for station 110...
# 56 outliers removed for station 111...
# 46 outliers removed for station 112...
# 35 outliers removed for station 113...
# 56 outliers removed for station 114...
# 52 outliers removed for station 115...
# 65 outliers removed for station 116...
# 80 outliers removed for station 117...
# 16 outliers removed for station 118...
# 63 outliers removed for station 119...
# 101 outliers removed for station 121...
# 64 outliers removed for station 122...
# 39 outliers removed for station 123...
# 14 outliers removed for station 124...
# 48 outliers removed for station 125...
# 41 outliers removed for station 126...
# 37 outliers removed for station 127...
# 72 outliers removed for station 128...
# 54 outliers removed for station 129...
# 96 outliers removed for station 130...
# 61 outliers removed for station 131...
# 68 outliers removed for station 132...
# 93 outliers removed for station 133...
# 54 outliers removed for station 134...
# 8 outliers removed for station 135...
# 33 outliers removed for station 137...
# 46 outliers removed for station 138...
# 96 outliers removed for station 140...
# 55 outliers removed for station 141...
# 72 outliers removed for station 142...
# 64 outliers removed for station 143...
# 54 outliers removed for station 144...
# 25 outliers removed for station 145...
# 48 outliers removed for station 146...
# 56 outliers removed for station 147...
# 89 outliers removed for station 148...
# 56 outliers removed for station 149...
# 50 outliers removed for station 150...
# 85 outliers removed for station 151...
# 37 outliers removed for station 152...
# 75 outliers removed for station 153...
# 33 outliers removed for station 154...
# 53 outliers removed for station 155...
# 88 outliers removed for station 156...
# 54 outliers removed for station 157...
# 63 outliers removed for station 158...
# 51 outliers removed for station 159...
# 33 outliers removed for station 160...
# 38 outliers removed for station 161...
# 41 outliers removed for station 162...
# 59 outliers removed for station 163...
# 17 outliers removed for station 164...
# 36 outliers removed for station 165...
# 37 outliers removed for station 166...
# 40 outliers removed for station 167...
# 55 outliers removed for station 168...
# 71 outliers removed for station 169...
# 61 outliers removed for station 170...
# 41 outliers removed for station 171...
# 39 outliers removed for station 172...
# 71 outliers removed for station 173...
# 49 outliers removed for station 174...
# 49 outliers removed for station 175...
# 52 outliers removed for station 176...
# 72 outliers removed for station 177...
# 70 outliers removed for station 178...
# 31 outliers removed for station 179...
# 40 outliers removed for station 180...
# 27 outliers removed for station 181...
# 47 outliers removed for station 182...
# 35 outliers removed for station 183...
# 41 outliers removed for station 184...
# 357 outliers removed for station 186...
# 41 outliers removed for station 187...
# 62 outliers removed for station 188...
# 56 outliers removed for station 189...
# 22 outliers removed for station 190...
# 68 outliers removed for station 191...
# 60 outliers removed for station 192...
# 105 outliers removed for station 193...
# 76 outliers removed for station 194...
# 30 outliers removed for station 195...
# 63 outliers removed for station 196...
# 58 outliers removed for station 197...
# 53 outliers removed for station 198...
# 72 outliers removed for station 199...
# 45 outliers removed for station 200...
# 56 outliers removed for station 201...
# 65 outliers removed for station 202...
# 58 outliers removed for station 203...
# 65 outliers removed for station 204...
# 24 outliers removed for station 205...
# 45 outliers removed for station 206...
# 99 outliers removed for station 207...
# 82 outliers removed for station 208...
# 118 outliers removed for station 209...
# 123 outliers removed for station 211...
# 83 outliers removed for station 212...
# 39 outliers removed for station 213...
# 55 outliers removed for station 214...
# 44 outliers removed for station 215...
# 52 outliers removed for station 216...
# 63 outliers removed for station 217...
# 48 outliers removed for station 218...
# 75 outliers removed for station 219...
# 73 outliers removed for station 220...
# 62 outliers removed for station 221...
# 90 outliers removed for station 222...
# 68 outliers removed for station 223...
# 59 outliers removed for station 224...
# 82 outliers removed for station 225...
# 20 outliers removed for station 226...
# 60 outliers removed for station 227...
# 70 outliers removed for station 228...
# 73 outliers removed for station 229...
# 50 outliers removed for station 230...
# 66 outliers removed for station 231...
# 78 outliers removed for station 232...
# 44 outliers removed for station 233...
# 85 outliers removed for station 234...
# 44 outliers removed for station 236...
# 62 outliers removed for station 237...
# 55 outliers removed for station 238...
# 60 outliers removed for station 239...
# 79 outliers removed for station 240...
# 38 outliers removed for station 241...
# 51 outliers removed for station 242...
# 25 outliers removed for station 243...
# 68 outliers removed for station 244...
# 48 outliers removed for station 245...
# 52 outliers removed for station 246...
# 41 outliers removed for station 247...
# 62 outliers removed for station 248...
# 59 outliers removed for station 249...
# 35 outliers removed for station 250...
# 44 outliers removed for station 251...
# 94 outliers removed for station 254...
# 51 outliers removed for station 255...
# 65 outliers removed for station 256...
# 37 outliers removed for station 257...
# 46 outliers removed for station 258...
# 62 outliers removed for station 259...
# 72 outliers removed for station 260...
# 108 outliers removed for station 261...
# 11 outliers removed for station 262...
# 12 outliers removed for station 263...
# 39 outliers removed for station 264...
# 59 outliers removed for station 265...
# 29 outliers removed for station 266...
# 32 outliers removed for station 267...
# 64 outliers removed for station 268...
# 25 outliers removed for station 269...
# 61 outliers removed for station 270...
# 29 outliers removed for station 271...
# 5 outliers removed for station 272...
# 49 outliers removed for station 273...
# 54 outliers removed for station 274...
# 57 outliers removed for station 275...
# 30 outliers removed for station 276...
# 55 outliers removed for station 277...
# 40 outliers removed for station 278...
# 98 outliers removed for station 279...
# 53 outliers removed for station 280...
# 29 outliers removed for station 281...
# 76 outliers removed for station 282...
# 6 outliers removed for station 283...
# 55 outliers removed for station 284...
# 54 outliers removed for station 285...
# 43 outliers removed for station 286...
# 44 outliers removed for station 287...
# 58 outliers removed for station 288...
# 40 outliers removed for station 289...
# 48 outliers removed for station 291...
# 60 outliers removed for station 292...
# 50 outliers removed for station 293...
# 34 outliers removed for station 294...
# 55 outliers removed for station 295...
# 91 outliers removed for station 296...
# 52 outliers removed for station 297...
# 42 outliers removed for station 298...
# 37 outliers removed for station 299...
# 80 outliers removed for station 300...
# 50 outliers removed for station 301...
# 28 outliers removed for station 302...
# 86 outliers removed for station 303...
# 53 outliers removed for station 304...
# 0 outliers removed for station 305...
# 78 outliers removed for station 306...
# 77 outliers removed for station 307...
# 68 outliers removed for station 308...
# 53 outliers removed for station 310...
# 48 outliers removed for station 311...
# 65 outliers removed for station 312...
# 56 outliers removed for station 313...
# 40 outliers removed for station 314...
# 61 outliers removed for station 315...
# 68 outliers removed for station 316...
# 25 outliers removed for station 317...
# 59 outliers removed for station 318...
# 55 outliers removed for station 319...
# 62 outliers removed for station 320...
# 34 outliers removed for station 322...
# 47 outliers removed for station 323...
# 54 outliers removed for station 324...
# 45 outliers removed for station 326...
# 44 outliers removed for station 327...
# 56 outliers removed for station 328...
# 47 outliers removed for station 329...
# 41 outliers removed for station 330...
# 60 outliers removed for station 332...
# 77 outliers removed for station 333...
# 60 outliers removed for station 334...
# 39 outliers removed for station 338...
# 23 outliers removed for station 339...
# 128 outliers removed for station 340...
# 68 outliers removed for station 341...
# 59 outliers removed for station 342...
# 60 outliers removed for station 343...
# 48 outliers removed for station 344...
# 51 outliers removed for station 347...
# 56 outliers removed for station 348...
# 61 outliers removed for station 349...
# 40 outliers removed for station 351...
# 42 outliers removed for station 352...
# 38 outliers removed for station 354...
# 73 outliers removed for station 356...
# 79 outliers removed for station 357...
# 34 outliers removed for station 358...
# 60 outliers removed for station 359...
# 44 outliers removed for station 360...
# 10 outliers removed for station 361...
# 39 outliers removed for station 362...
# 80 outliers removed for station 363...
# 58 outliers removed for station 364...
# 49 outliers removed for station 365...
# 52 outliers removed for station 366...
# 83 outliers removed for station 367...
# 9 outliers removed for station 369...
# 8 outliers removed for station 370...
# 48 outliers removed for station 372...
# 75 outliers removed for station 374...
# 78 outliers removed for station 375...
# 62 outliers removed for station 376...
# 74 outliers removed for station 380...
# 63 outliers removed for station 381...
# 86 outliers removed for station 382...
# 36 outliers removed for station 383...
# 68 outliers removed for station 384...
# 63 outliers removed for station 385...
# 47 outliers removed for station 389...
# 27 outliers removed for station 390...
# 82 outliers removed for station 392...
# 42 outliers removed for station 393...
# 91 outliers removed for station 394...
# 22 outliers removed for station 395...
# 71 outliers removed for station 396...
# 83 outliers removed for station 397...
# 57 outliers removed for station 399...
# 48 outliers removed for station 400...
# 71 outliers removed for station 402...
# 32 outliers removed for station 403...
# 83 outliers removed for station 404...
# 36 outliers removed for station 405...
# 39 outliers removed for station 407...
# 8 outliers removed for station 408...
# 61 outliers removed for station 410...
# 87 outliers removed for station 411...
# 69 outliers removed for station 412...
# 75 outliers removed for station 413...
# 55 outliers removed for station 414...
# 46 outliers removed for station 415...
# 46 outliers removed for station 416...
# 68 outliers removed for station 417...
# 32 outliers removed for station 418...
# 39 outliers removed for station 419...
# 53 outliers removed for station 420...
# 36 outliers removed for station 421...
# 125 outliers removed for station 422...
# 38 outliers removed for station 423...
# 61 outliers removed for station 424...
# 60 outliers removed for station 425...
# 70 outliers removed for station 426...
# 26 outliers removed for station 427...
# 60 outliers removed for station 429...
# 35 outliers removed for station 431...
# 52 outliers removed for station 432...
# 47 outliers removed for station 433...
# 61 outliers removed for station 434...
# 47 outliers removed for station 435...
# 62 outliers removed for station 436...
# 46 outliers removed for station 437...
# 40 outliers removed for station 438...
# 57 outliers removed for station 447...
# 58 outliers removed for station 448...
# 66 outliers removed for station 449...
# 42 outliers removed for station 450...
# 52 outliers removed for station 452...
# 87 outliers removed for station 453...
# 74 outliers removed for station 454...
# 38 outliers removed for station 455...
# 52 outliers removed for station 456...
# 55 outliers removed for station 457...
# 41 outliers removed for station 458...
# 92 outliers removed for station 459...
# 65 outliers removed for station 460...
# 38 outliers removed for station 461...
# 30 outliers removed for station 463...
# 45 outliers removed for station 464...
# 48 outliers removed for station 465...
# 30 outliers removed for station 466...
# 41 outliers removed for station 471...
# 44 outliers removed for station 472...
# 23 outliers removed for station 473...
# 51 outliers removed for station 475...
# 34 outliers removed for station 479...
# 97 outliers removed for station 481...
# 67 outliers removed for station 482...
# 67 outliers removed for station 483...
# 30 outliers removed for station 484...
# 68 outliers removed for station 485...
# 22 outliers removed for station 486...
# 70 outliers removed for station 487...
# 56 outliers removed for station 488...
# 58 outliers removed for station 489...
# 59 outliers removed for station 490...
# 36 outliers removed for station 491...
# 52 outliers removed for station 492...
# 38 outliers removed for station 493...
# 47 outliers removed for station 494...
# 49 outliers removed for station 495...
# 62 outliers removed for station 497...
# 44 outliers removed for station 498...
# 47 outliers removed for station 499...
# 54 outliers removed for station 501...
# 57 outliers removed for station 502...
# 76 outliers removed for station 503...
# 54 outliers removed for station 504...
# 54 outliers removed for station 506...
# 56 outliers removed for station 507...
# 43 outliers removed for station 508...
# 40 outliers removed for station 509...
# 29 outliers removed for station 510...
# 60 outliers removed for station 511...
# 61 outliers removed for station 514...
# 54 outliers removed for station 515...
# 42 outliers removed for station 518...
# 52 outliers removed for station 521...
# 66 outliers removed for station 523...
# 28 outliers removed for station 525...
# 59 outliers removed for station 528...
# 48 outliers removed for station 532...
# 46 outliers removed for station 534...
# 44 outliers removed for station 535...
# 13 outliers removed for station 536...
# 54 outliers removed for station 537...
# 60 outliers removed for station 538...
# 59 outliers removed for station 539...
# 60 outliers removed for station 540...
# 52 outliers removed for station 541...
# 50 outliers removed for station 542...
# 55 outliers removed for station 543...
# 40 outliers removed for station 544...
# 58 outliers removed for station 545...
# 34 outliers removed for station 548...
# 55 outliers removed for station 549...
# 76 outliers removed for station 551...
# 63 outliers removed for station 554...
# 48 outliers removed for station 555...
# 51 outliers removed for station 557...
# 72 outliers removed for station 558...
# 43 outliers removed for station 559...
# 37 outliers removed for station 560...
# 50 outliers removed for station 562...
# 54 outliers removed for station 563...
# 49 outliers removed for station 565...
# 59 outliers removed for station 566...
# 69 outliers removed for station 568...
# 26 outliers removed for station 569...
# 62 outliers removed for station 570...
# 50 outliers removed for station 571...
# 49 outliers removed for station 573...
# 77 outliers removed for station 574...
# 36 outliers removed for station 575...
# 48 outliers removed for station 576...
# 66 outliers removed for station 577...
# 45 outliers removed for station 578...
# 14 outliers removed for station 579...
# 62 outliers removed for station 580...
# 60 outliers removed for station 582...
# 16 outliers removed for station 584...
# 51 outliers removed for station 586...
# 55 outliers removed for station 587...
# 108 outliers removed for station 588...
# 52 outliers removed for station 589...
# 85 outliers removed for station 590...
# 67 outliers removed for station 591...
# 66 outliers removed for station 592...
# 76 outliers removed for station 593...
# 64 outliers removed for station 594...
# 44 outliers removed for station 595...
# 60 outliers removed for station 596...
# 159 outliers removed for station 597...
# 44 outliers removed for station 598...
# 52 outliers removed for station 599...
# 146 outliers removed for station 603...
# 37 outliers removed for station 604...
# 300 outliers removed for station 606...
# 81 outliers removed for station 611...
# 150 outliers removed for station 612...
# 154 outliers removed for station 613...
# 111 outliers removed for station 616...
# 51 outliers removed for station 617...
# 101 outliers removed for station 619...
# 96 outliers removed for station 621...
# 62 outliers removed for station 622...
# 99 outliers removed for station 623...
# 60 outliers removed for station 624...
# 75 outliers removed for station 626...
# 63 outliers removed for station 627...
# 89 outliers removed for station 628...
# 58 outliers removed for station 629...
# 89 outliers removed for station 630...
# 43 outliers removed for station 632...
# 48 outliers removed for station 634...
# 46 outliers removed for station 636...
# 101 outliers removed for station 637...
# 72 outliers removed for station 638...
# 64 outliers removed for station 640...
# 70 outliers removed for station 641...
# 49 outliers removed for station 642...
# 70 outliers removed for station 645...
# 115 outliers removed for station 646...
# 79 outliers removed for station 647...
# 58 outliers removed for station 649...
# 168 outliers removed for station 650...
# 42 outliers removed for station 652...
# 186 outliers removed for station 653...
# 60 outliers removed for station 654...
# 108 outliers removed for station 655...
# 164 outliers removed for station 656...
# 195 outliers removed for station 657...
# 177 outliers removed for station 658...
# 81 outliers removed for station 661...
# 111 outliers removed for station 662...
# 89 outliers removed for station 665...
# 200 outliers removed for station 666...
# 70 outliers removed for station 667...
# 75 outliers removed for station 668...
# 23 outliers removed for station 670...
# 132 outliers removed for station 671...
# 136 outliers removed for station 672...
# 21 outliers removed for station 673...
# 22 outliers removed for station 674...
# 63 outliers removed for station 675...
# 52 outliers removed for station 676...
# 39 outliers removed for station 678...
# 16 outliers removed for station 679...
# 59 outliers removed for station 681...
# 35 outliers removed for station 682...
# 73 outliers removed for station 683...
# 27 outliers removed for station 686...
# 0 outliers removed for station 689...
# 47 outliers removed for station 691...
# 88 outliers removed for station 692...
# 165 outliers removed for station 694...
# 69 outliers removed for station 696...
# 60 outliers removed for station 700...
# 58 outliers removed for station 704...
# 72 outliers removed for station 705...
# 24 outliers removed for station 706...
# 37 outliers removed for station 708...
# 36 outliers removed for station 714...
# 24 outliers removed for station 731...
# 51 outliers removed for station 732...
# 19 outliers removed for station 733...
# 19 outliers removed for station 735...
# 32 outliers removed for station 737...
# 40 outliers removed for station 738...
# 30 outliers removed for station 739...
# 49 outliers removed for station 740...
# 46 outliers removed for station 741...
# 38 outliers removed for station 742...
# 17 outliers removed for station 743...
# 41 outliers removed for station 744...
# 15 outliers removed for station 746...
# 46 outliers removed for station 747...
# 73 outliers removed for station 749...
# 48 outliers removed for station 750...
# 51 outliers removed for station 751...
# 41 outliers removed for station 752...
# 49 outliers removed for station 753...
# 50 outliers removed for station 756...
# 19 outliers removed for station 757...
# 13 outliers removed for station 758...
# 20 outliers removed for station 759...
# 56 outliers removed for station 760...
# 27 outliers removed for station 761...
# 21 outliers removed for station 762...
# 29 outliers removed for station 763...
# 32 outliers removed for station 764...
# 42 outliers removed for station 765...
# 33 outliers removed for station 766...
# 42 outliers removed for station 767...
# 86 outliers removed for station 768...
# 33 outliers removed for station 769...
# 41 outliers removed for station 770...
# 33 outliers removed for station 771...
# 35 outliers removed for station 772...
# 30 outliers removed for station 773...
# 60 outliers removed for station 774...
# 30 outliers removed for station 776...
# 32 outliers removed for station 777...
# 48 outliers removed for station 778...
# 66 outliers removed for station 779...
# 120 outliers removed for station 781...
# 46 outliers removed for station 782...
# 44 outliers removed for station 783...
# 49 outliers removed for station 784...
# 85 outliers removed for station 785...
# 22 outliers removed for station 788...
# 64 outliers removed for station 789...
# 93 outliers removed for station 791...
# 17 outliers removed for station 792...
# 43 outliers removed for station 793...
# 43 outliers removed for station 794...
# 118 outliers removed for station 795...
# 37 outliers removed for station 796...
# 81 outliers removed for station 797...
# 85 outliers removed for station 798...
# 38 outliers removed for station 799...
# 57 outliers removed for station 800...
# 53 outliers removed for station 803...
# 50 outliers removed for station 804...
# 96 outliers removed for station 805...
# 57 outliers removed for station 806...
# 47 outliers removed for station 807...
# 54 outliers removed for station 809...
# 65 outliers removed for station 810...
# 49 outliers removed for station 811...
# 53 outliers removed for station 813...
# 60 outliers removed for station 814...
# 59 outliers removed for station 815...
# 34 outliers removed for station 816...
# 65 outliers removed for station 817...
# 49 outliers removed for station 818...
# 44 outliers removed for station 820...
# 87 outliers removed for station 821...
# 56 outliers removed for station 822...
# 87 outliers removed for station 823...
# 169 outliers removed for station 824...
# 45 outliers removed for station 825...
# 122 outliers removed for station 826...
# 43 outliers removed for station 827...
# 89 outliers removed for station 828...
# 78 outliers removed for station 829...
# 74 outliers removed for station 830...
# 35 outliers removed for station 831...
# 58 outliers removed for station 832...
# 69 outliers removed for station 833...
# 27 outliers removed for station 835...
# 8 outliers removed for station 836...
# 47 outliers removed for station 837...
# 46 outliers removed for station 838...
# 50 outliers removed for station 840...
# 11 outliers removed for station 841...
# 90 outliers removed for station 842...
# 93 outliers removed for station 843...
# 99 outliers removed for station 844...
# 101 outliers removed for station 845...
# 63 outliers removed for station 846...
# 173 outliers removed for station 847...
# 65 outliers removed for station 849...
# 58 outliers removed for station 850...
# 54 outliers removed for station 851...
# 77 outliers removed for station 853...
# 71 outliers removed for station 855...
# 84 outliers removed for station 856...
# 88 outliers removed for station 859...
# 75 outliers removed for station 860...
# 60 outliers removed for station 861...
# 84 outliers removed for station 862...
# 74 outliers removed for station 863...
# 47 outliers removed for station 864...
# 59 outliers removed for station 865...
# 105 outliers removed for station 866...
# 47 outliers removed for station 867...
# 72 outliers removed for station 868...
# 6 outliers removed for station 869...
# 52 outliers removed for station 870...
# 54 outliers removed for station 871...
# 91 outliers removed for station 872...
# 34 outliers removed for station 873...
# 19 outliers removed for station 874...
# 15 outliers removed for station 875...
# 11 outliers removed for station 876...
# 56 outliers removed for station 877...
# 15 outliers removed for station 878...
# 33 outliers removed for station 879...
# 19 outliers removed for station 880...
# 33 outliers removed for station 882...
# 28 outliers removed for station 883...
# 19 outliers removed for station 884...
# 53 outliers removed for station 885...
# 40 outliers removed for station 890...
# 24 outliers removed for station 893...
# 35 outliers removed for station 896...
# 58 outliers removed for station 899...
# 63 outliers removed for station 900...
# 79 outliers removed for station 901...
# 93 outliers removed for station 902...
# 125 outliers removed for station 903...
# 136 outliers removed for station 904...
# 115 outliers removed for station 905...
# 208 outliers removed for station 906...
# 73 outliers removed for station 907...
# 167 outliers removed for station 909...
# 16 outliers removed for station 910...
# 122 outliers removed for station 912...
# 25 outliers removed for station 913...
# 118 outliers removed for station 914...
# 90 outliers removed for station 915...
# 146 outliers removed for station 916...
# 196 outliers removed for station 918...
# 173 outliers removed for station 919...
# 180 outliers removed for station 920...
# 201 outliers removed for station 921...
# 52 outliers removed for station 922...
# 65 outliers removed for station 923...
# 95 outliers removed for station 925...
# 23 outliers removed for station 927...
# 49 outliers removed for station 928...
# 122 outliers removed for station 931...
# 85 outliers removed for station 933...
# 69 outliers removed for station 934...
# 53 outliers removed for station 935...
# 71 outliers removed for station 936...
# 30 outliers removed for station 937...
# 32 outliers removed for station 938...
# 106 outliers removed for station 939...
# 60 outliers removed for station 940...
# 71 outliers removed for station 941...
# 77 outliers removed for station 942...
# 3 outliers removed for station 943...
# 5 outliers removed for station 944...
# 30 outliers removed for station 946...
# 142 outliers removed for station 947...
# 55 outliers removed for station 949...
# 81 outliers removed for station 950...
# 46 outliers removed for station 951...
# 71 outliers removed for station 952...
# 71 outliers removed for station 953...
# 38 outliers removed for station 954...
# 90 outliers removed for station 955...
# 77 outliers removed for station 957...
# 45 outliers removed for station 958...
# 50 outliers removed for station 959...
# 50 outliers removed for station 961...
# 74 outliers removed for station 964...
# 80 outliers removed for station 967...
# 58 outliers removed for station 969...
# 80 outliers removed for station 970...
# 128 outliers removed for station 971...
# 68 outliers removed for station 973...
# 61 outliers removed for station 974...
# 53 outliers removed for station 975...
# 68 outliers removed for station 976...
# 57 outliers removed for station 977...
# 96 outliers removed for station 980...
# 57 outliers removed for station 981...
# 74 outliers removed for station 982...
# 44 outliers removed for station 983...
# 72 outliers removed for station 984...
# 55 outliers removed for station 986...
# 57 outliers removed for station 987...
# 78 outliers removed for station 988...
# 62 outliers removed for station 989...
# 53 outliers removed for station 990...
# 44 outliers removed for station 992...
# 42 outliers removed for station 993...
# 67 outliers removed for station 994...
# 61 outliers removed for station 996...
# 38 outliers removed for station 998...
# 51 outliers removed for station 1000...
# 30 outliers removed for station 1001...
# 88 outliers removed for station 1002...
# 40 outliers removed for station 1003...
# 101 outliers removed for station 1004...
# 51 outliers removed for station 1005...
# 39 outliers removed for station 1006...
# 72 outliers removed for station 1007...
# 57 outliers removed for station 1008...
# 36 outliers removed for station 1009...
# 51 outliers removed for station 1010...
# 89 outliers removed for station 1011...
# 60 outliers removed for station 1012...
# 56 outliers removed for station 1013...
# 60 outliers removed for station 1014...
# 40 outliers removed for station 1015...
# 45 outliers removed for station 1016...
# 67 outliers removed for station 1017...
# 57 outliers removed for station 1018...
# 73 outliers removed for station 1019...
# 60 outliers removed for station 1053...
# 66 outliers removed for station 1054...
# 86 outliers removed for station 1055...
# 64 outliers removed for station 1056...
# 62 outliers removed for station 1057...
# 39 outliers removed for station 1059...
# 35 outliers removed for station 1061...
# 51 outliers removed for station 1062...
# 63 outliers removed for station 1064...
# 27 outliers removed for station 1065...
# 27 outliers removed for station 1068...
# 85 outliers removed for station 1069...
# 76 outliers removed for station 1070...
# 72 outliers removed for station 1071...
# 77 outliers removed for station 1072...
# 78 outliers removed for station 1073...
# 55 outliers removed for station 1074...
# 63 outliers removed for station 1075...
# 82 outliers removed for station 1076...
# 89 outliers removed for station 1077...
# 59 outliers removed for station 1078...
# 77 outliers removed for station 1079...
# 102 outliers removed for station 1080...
# 57 outliers removed for station 1081...
# 13 outliers removed for station 1082...
# 86 outliers removed for station 1083...
# 50 outliers removed for station 1084...
# 57 outliers removed for station 1085...
# 72 outliers removed for station 1086...
# 102 outliers removed for station 1087...
# 89 outliers removed for station 1088...
# 80 outliers removed for station 1089...
# 68 outliers removed for station 1090...
# 38 outliers removed for station 1091...
# 85 outliers removed for station 1092...
# 25 outliers removed for station 1093...
# 80 outliers removed for station 1094...
# 62 outliers removed for station 1095...
# 60 outliers removed for station 1096...
# 63 outliers removed for station 1097...
# 96 outliers removed for station 1098...
# 57 outliers removed for station 1099...
# 82 outliers removed for station 1100...
# 85 outliers removed for station 1103...
# 90 outliers removed for station 1104...
# 37 outliers removed for station 1105...
# 19 outliers removed for station 1106...
# 28 outliers removed for station 1107...
# 74 outliers removed for station 1108...
# 159 outliers removed for station 1109...
# 74 outliers removed for station 1110...
# 48 outliers removed for station 1111...
# 54 outliers removed for station 1112...
# 83 outliers removed for station 1113...
# 57 outliers removed for station 1114...
# 58 outliers removed for station 1116...
# 52 outliers removed for station 1117...
# 73 outliers removed for station 1118...
# 94 outliers removed for station 1119...
# 69 outliers removed for station 1121...
# 67 outliers removed for station 1122...
# 50 outliers removed for station 1124...
# 74 outliers removed for station 1125...
# 89 outliers removed for station 1127...
# 100 outliers removed for station 1128...
# 38 outliers removed for station 1129...
# 71 outliers removed for station 1130...
# 83 outliers removed for station 1132...
# 69 outliers removed for station 1135...
# 99 outliers removed for station 1136...
# 65 outliers removed for station 1137...
# 90 outliers removed for station 1140...
# 53 outliers removed for station 1141...
# 31 outliers removed for station 1142...
# 89 outliers removed for station 1143...
# 96 outliers removed for station 1144...
# 45 outliers removed for station 1147...
# 75 outliers removed for station 1149...
# 84 outliers removed for station 1150...
# 79 outliers removed for station 1151...
# 67 outliers removed for station 1152...
# 63 outliers removed for station 1153...
# 86 outliers removed for station 1154...
# 78 outliers removed for station 1155...
# 72 outliers removed for station 1156...
# 105 outliers removed for station 1158...
# 67 outliers removed for station 1159...
# 52 outliers removed for station 1161...
# 12 outliers removed for station 1162...
# 28 outliers removed for station 1163...
# 56 outliers removed for station 1164...
# 58 outliers removed for station 1185...
# 79 outliers removed for station 1186...
# 64 outliers removed for station 1187...
# 57 outliers removed for station 1188...
# 12 outliers removed for station 1189...
# 82 outliers removed for station 1190...
# 67 outliers removed for station 1191...
# 81 outliers removed for station 1192...
# 97 outliers removed for station 1193...
# 82 outliers removed for station 1194...
# 98 outliers removed for station 1195...
# 54 outliers removed for station 1196...
# 64 outliers removed for station 1197...
# 56 outliers removed for station 1198...
# 128 outliers removed for station 1199...
# 91 outliers removed for station 1200...
# 77 outliers removed for station 1201...
# 18 outliers removed for station 1202...
# 34 outliers removed for station 1203...
# 62 outliers removed for station 1204...
# 33 outliers removed for station 1205...
# 64 outliers removed for station 1207...
# 73 outliers removed for station 1208...
# 80 outliers removed for station 1209...
# 98 outliers removed for station 1210...
# 49 outliers removed for station 1211...
# 65 outliers removed for station 1212...
# 35 outliers removed for station 1213...
# 36 outliers removed for station 1214...
# 93 outliers removed for station 1215...
# 47 outliers removed for station 1216...
# 77 outliers removed for station 1217...
# 88 outliers removed for station 1218...
# 81 outliers removed for station 1219...
# 88 outliers removed for station 1220...
# 25 outliers removed for station 1221...
# 47 outliers removed for station 1222...
# 77 outliers removed for station 1223...
# 84 outliers removed for station 1224...
# 90 outliers removed for station 1225...
# 54 outliers removed for station 1226...
# 49 outliers removed for station 1227...
# 82 outliers removed for station 1228...
# 73 outliers removed for station 1229...
# 62 outliers removed for station 1230...
# 77 outliers removed for station 1231...
# 10 outliers removed for station 1232...
# 56 outliers removed for station 1233...
# 20 outliers removed for station 1234...
# 50 outliers removed for station 1235...
# 79 outliers removed for station 1236...
# 27 outliers removed for station 1237...
# 39 outliers removed for station 1238...
# 69 outliers removed for station 1239...
# 70 outliers removed for station 1240...
# 92 outliers removed for station 1244...
# 44 outliers removed for station 1246...
# 68 outliers removed for station 1248...
# 103 outliers removed for station 1250...
# 68 outliers removed for station 1251...
# 102 outliers removed for station 1254...
# 59 outliers removed for station 1261...
# 55 outliers removed for station 1264...
# 72 outliers removed for station 1269...
# 72 outliers removed for station 1271...
# 64 outliers removed for station 1273...
# 67 outliers removed for station 1274...
# 69 outliers removed for station 1275...
# 49 outliers removed for station 1276...
# 65 outliers removed for station 1277...
# 79 outliers removed for station 1278...
# 52 outliers removed for station 1279...
# 31 outliers removed for station 1280...
# 60 outliers removed for station 1281...
# 41 outliers removed for station 1282...
# 38 outliers removed for station 1283...
# 52 outliers removed for station 1284...
# 104 outliers removed for station 1285...
# 42 outliers removed for station 1286...
# 49 outliers removed for station 1287...
# 7 outliers removed for station 1288...
# 61 outliers removed for station 1289...
# 37 outliers removed for station 1290...
# 81 outliers removed for station 1291...
# 55 outliers removed for station 1292...
# 61 outliers removed for station 1293...
# 74 outliers removed for station 1294...
# 65 outliers removed for station 1295...
# 59 outliers removed for station 1296...
# 52 outliers removed for station 1297...
# 71 outliers removed for station 1298...
# 75 outliers removed for station 1301...
# 19 outliers removed for station 1302...
# 5 outliers removed for station 1303...
# 49 outliers removed for station 1304...
# 80 outliers removed for station 1305...
# 53 outliers removed for station 1306...
# 45 outliers removed for station 1307...
# 124 outliers removed for station 1308...
# 75 outliers removed for station 1309...
# 11 outliers removed for station 1310...
# 83 outliers removed for station 1312...
# 52 outliers removed for station 1313...
# 47 outliers removed for station 1315...
# 126 outliers removed for station 1316...
# 55 outliers removed for station 1319...
# 68 outliers removed for station 1320...
# 25 outliers removed for station 1321...
# 77 outliers removed for station 1322...
# 63 outliers removed for station 1323...
# 40 outliers removed for station 1324...
# 86 outliers removed for station 1326...
# 81 outliers removed for station 1327...
# 47 outliers removed for station 1330...
# 15 outliers removed for station 1332...
# 78 outliers removed for station 1334...
# 63 outliers removed for station 1336...
# 81 outliers removed for station 1337...
# 96 outliers removed for station 1338...
# 74 outliers removed for station 1339...
# 73 outliers removed for station 1340...
# 44 outliers removed for station 1345...
# 93 outliers removed for station 1346...
# 56 outliers removed for station 1347...
# 86 outliers removed for station 1348...
# 43 outliers removed for station 1349...
# 72 outliers removed for station 1350...
# 73 outliers removed for station 1352...
# 77 outliers removed for station 1353...
# 48 outliers removed for station 1354...
# 70 outliers removed for station 1355...
# 92 outliers removed for station 1356...
# 74 outliers removed for station 1357...
# 75 outliers removed for station 1358...
# 147 outliers removed for station 1359...
# 86 outliers removed for station 1360...
# 37 outliers removed for station 1361...
# 100 outliers removed for station 1362...
# 94 outliers removed for station 1363...
# 117 outliers removed for station 1365...
# 76 outliers removed for station 1366...
# 71 outliers removed for station 1367...
# 68 outliers removed for station 1368...
# 91 outliers removed for station 1369...
# 66 outliers removed for station 1370...
# 47 outliers removed for station 1371...
# 89 outliers removed for station 1372...
# 77 outliers removed for station 1373...
# 78 outliers removed for station 1374...
# 49 outliers removed for station 1375...
# 73 outliers removed for station 1378...
# 37 outliers removed for station 1379...
# 36 outliers removed for station 1380...
# 10 outliers removed for station 1381...
# 62 outliers removed for station 1382...
# 45 outliers removed for station 1383...
# 82 outliers removed for station 1384...
# 88 outliers removed for station 1385...
# 30 outliers removed for station 1386...
# 70 outliers removed for station 1387...
# 48 outliers removed for station 1388...
# 76 outliers removed for station 1389...
# 94 outliers removed for station 1390...
# 97 outliers removed for station 1391...
# 39 outliers removed for station 1392...
# 56 outliers removed for station 1393...
# 84 outliers removed for station 1394...
# 36 outliers removed for station 1395...
# 59 outliers removed for station 1396...
# 19 outliers removed for station 1397...
# 31 outliers removed for station 1398...
# 111 outliers removed for station 1399...
# 70 outliers removed for station 1400...
# 44 outliers removed for station 1401...
# 80 outliers removed for station 1402...
# 59 outliers removed for station 1403...
# 97 outliers removed for station 1404...
# 60 outliers removed for station 1405...
# 94 outliers removed for station 1406...
# 49 outliers removed for station 1407...
# 10 outliers removed for station 1408...
# 15 outliers removed for station 1409...
# 140 outliers removed for station 1410...
# 67 outliers removed for station 1411...
# 59 outliers removed for station 1412...
# 63 outliers removed for station 1413...
# 118 outliers removed for station 1414...
# 71 outliers removed for station 1415...
# 46 outliers removed for station 1416...
# 60 outliers removed for station 1417...
# 67 outliers removed for station 1418...
# 89 outliers removed for station 1419...
# 76 outliers removed for station 1420...
# 66 outliers removed for station 1421...
# 94 outliers removed for station 1422...
# 61 outliers removed for station 1423...
# 37 outliers removed for station 1424...
# 112 outliers removed for station 1425...
# 59 outliers removed for station 1426...
# 58 outliers removed for station 1427...
# 62 outliers removed for station 1428...
# 61 outliers removed for station 1429...
# 17 outliers removed for station 1430...
# 32 outliers removed for station 1431...
# 78 outliers removed for station 1432...
# 43 outliers removed for station 1433...
# 55 outliers removed for station 1434...
# 27 outliers removed for station 1435...
# 95 outliers removed for station 1436...
# 84 outliers removed for station 1437...
# 83 outliers removed for station 1438...
# 52 outliers removed for station 1439...
# 87 outliers removed for station 1440...
# 120 outliers removed for station 1443...
# 71 outliers removed for station 1444...
# 91 outliers removed for station 1445...
# 40 outliers removed for station 1446...
# 37 outliers removed for station 1447...
# 73 outliers removed for station 1448...
# 40 outliers removed for station 1449...
# 73 outliers removed for station 1450...
# 52 outliers removed for station 1451...
# 80 outliers removed for station 1452...
# 45 outliers removed for station 1453...
# 66 outliers removed for station 1454...
# 58 outliers removed for station 1455...
# 69 outliers removed for station 1456...
# 64 outliers removed for station 1457...
# 16 outliers removed for station 1458...
# 42 outliers removed for station 1459...
# 57 outliers removed for station 1460...
# 127 outliers removed for station 1461...
# 50 outliers removed for station 1462...
# 68 outliers removed for station 1463...
# 71 outliers removed for station 1464...
# 64 outliers removed for station 1465...
# 137 outliers removed for station 1466...
# 69 outliers removed for station 1467...
# 62 outliers removed for station 1468...
# 113 outliers removed for station 1469...
# 77 outliers removed for station 1470...
# 59 outliers removed for station 1471...
# 111 outliers removed for station 1472...
# 75 outliers removed for station 1473...
# 54 outliers removed for station 1474...
# 54 outliers removed for station 1475...
# 76 outliers removed for station 1476...
# 88 outliers removed for station 1477...
# 70 outliers removed for station 1480...
# 65 outliers removed for station 1481...
# 52 outliers removed for station 1482...
# 116 outliers removed for station 1484...
# 86 outliers removed for station 1485...
# 70 outliers removed for station 1486...
# 55 outliers removed for station 1487...
# 132 outliers removed for station 1488...
# 83 outliers removed for station 1489...
# 86 outliers removed for station 1490...
# 70 outliers removed for station 1491...
# 41 outliers removed for station 1492...
# 73 outliers removed for station 1493...
# 67 outliers removed for station 1494...
# 84 outliers removed for station 1495...
# 70 outliers removed for station 1496...
# 64 outliers removed for station 1497...
# 52 outliers removed for station 1498...
# 45 outliers removed for station 1499...
# 72 outliers removed for station 1500...
# 44 outliers removed for station 1502...
# 60 outliers removed for station 1503...
# 74 outliers removed for station 1504...
# 83 outliers removed for station 1505...
# 67 outliers removed for station 1507...
# 86 outliers removed for station 1508...
# 36 outliers removed for station 1509...
# 57 outliers removed for station 1510...
# 112 outliers removed for station 1511...
# 41 outliers removed for station 1512...
# 37 outliers removed for station 1513...
# 54 outliers removed for station 1514...
# 110 outliers removed for station 1515...
# 39 outliers removed for station 1516...
# 96 outliers removed for station 1517...
# 57 outliers removed for station 1518...
# 50 outliers removed for station 1519...
# 77 outliers removed for station 1520...
# 44 outliers removed for station 1521...
# 71 outliers removed for station 1522...
# 20 outliers removed for station 1523...
# 66 outliers removed for station 1524...
# 217 outliers removed for station 1525...
# 34 outliers removed for station 1526...
# 73 outliers removed for station 1527...
# 50 outliers removed for station 1528...
# 56 outliers removed for station 1529...
# 22 outliers removed for station 1530...
# 105 outliers removed for station 1531...
# 68 outliers removed for station 1532...
# 57 outliers removed for station 1533...
# 13 outliers removed for station 1534...
# 85 outliers removed for station 1535...
# 47 outliers removed for station 1536...
# 54 outliers removed for station 1537...
# 73 outliers removed for station 1538...
# 58 outliers removed for station 1539...
# 28 outliers removed for station 1540...
# 55 outliers removed for station 1541...
# 1 outliers removed for station 1542...
# 49 outliers removed for station 1543...
# 119 outliers removed for station 1544...
# 31 outliers removed for station 1545...
# 54 outliers removed for station 1546...
# 45 outliers removed for station 1548...
# 78 outliers removed for station 1550...
# 64 outliers removed for station 1552...
# 47 outliers removed for station 1553...
# 73 outliers removed for station 1554...
# 24 outliers removed for station 1555...
# 122 outliers removed for station 1556...
# 66 outliers removed for station 1557...
# 68 outliers removed for station 1558...
# 31 outliers removed for station 1559...
# 100 outliers removed for station 1560...
# 61 outliers removed for station 1561...
# 84 outliers removed for station 1562...
# 109 outliers removed for station 1563...
# 67 outliers removed for station 1564...
# 75 outliers removed for station 1565...
# 66 outliers removed for station 1566...
# 54 outliers removed for station 1567...
# 73 outliers removed for station 1568...
# 70 outliers removed for station 1569...
# 104 outliers removed for station 1571...
# 85 outliers removed for station 1572...
# 49 outliers removed for station 1573...
# 59 outliers removed for station 1576...
# 81 outliers removed for station 1577...
# 32 outliers removed for station 1578...
# 70 outliers removed for station 1579...
# 11 outliers removed for station 1580...
# 132 outliers removed for station 1581...
# 66 outliers removed for station 1582...
# 74 outliers removed for station 1583...
# 57 outliers removed for station 1584...
# 40 outliers removed for station 1585...
# 90 outliers removed for station 1586...
# 109 outliers removed for station 1587...
# 82 outliers removed for station 1588...
# 180 outliers removed for station 1589...
# 73 outliers removed for station 1590...
# 43 outliers removed for station 1591...
# 75 outliers removed for station 1592...
# 88 outliers removed for station 1593...
# 23 outliers removed for station 1594...
# 86 outliers removed for station 1595...
# 80 outliers removed for station 1596...
# 58 outliers removed for station 1597...
# 77 outliers removed for station 1598...
# 31 outliers removed for station 1599...
# 59 outliers removed for station 1600...
# 136 outliers removed for station 1601...
# 40 outliers removed for station 1602...
# 61 outliers removed for station 1604...
# 6 outliers removed for station 1605...
# 62 outliers removed for station 1606...
# 64 outliers removed for station 1607...
# 56 outliers removed for station 1608...
# 68 outliers removed for station 1609...
# 66 outliers removed for station 1611...
# 85 outliers removed for station 1612...
# 103 outliers removed for station 1614...
# 86 outliers removed for station 1615...
# 140 outliers removed for station 1616...
# 110 outliers removed for station 1617...
# 49 outliers removed for station 1619...
# 123 outliers removed for station 1620...
# 46 outliers removed for station 1623...
# 39 outliers removed for station 1624...
# 141 outliers removed for station 1626...
# 65 outliers removed for station 1628...
# 74 outliers removed for station 1629...
# 28 outliers removed for station 1630...
# 76 outliers removed for station 1631...
# 96 outliers removed for station 1632...
# 86 outliers removed for station 1633...
# 50 outliers removed for station 1634...
# 47 outliers removed for station 1636...
# 69 outliers removed for station 1637...
# 118 outliers removed for station 1638...
# 42 outliers removed for station 1639...
# 54 outliers removed for station 1640...
# 88 outliers removed for station 1641...
# 65 outliers removed for station 1642...
# 46 outliers removed for station 1643...
# 88 outliers removed for station 1644...
# 28 outliers removed for station 1645...
# 65 outliers removed for station 1646...
# 53 outliers removed for station 1647...
# 60 outliers removed for station 1648...
# 57 outliers removed for station 1649...
# 50 outliers removed for station 1650...
# 101 outliers removed for station 1651...
# 106 outliers removed for station 1652...
# 85 outliers removed for station 1653...
# 49 outliers removed for station 1654...
# 220 outliers removed for station 1656...
# 66 outliers removed for station 1657...
# 57 outliers removed for station 1658...
# 77 outliers removed for station 1661...
# 105 outliers removed for station 1670...
# 50 outliers removed for station 1671...
# 110 outliers removed for station 1673...
# 77 outliers removed for station 1674...
# 43 outliers removed for station 1680...
# 35 outliers removed for station 1681...
# 63 outliers removed for station 1682...
# 55 outliers removed for station 1683...
# 70 outliers removed for station 1684...
# 45 outliers removed for station 1685...
# 23 outliers removed for station 1686...
# 80 outliers removed for station 1687...
# 108 outliers removed for station 1688...
# 103 outliers removed for station 1689...
# 41 outliers removed for station 1690...
# 54 outliers removed for station 1691...
# 62 outliers removed for station 1692...
# 63 outliers removed for station 1693...
# 79 outliers removed for station 1694...
# 29 outliers removed for station 1695...
# 45 outliers removed for station 1696...
# 26 outliers removed for station 1697...
# 62 outliers removed for station 1698...
# 38 outliers removed for station 1699...
# 102 outliers removed for station 1700...
# 82 outliers removed for station 1701...
# 59 outliers removed for station 1702...
# 48 outliers removed for station 1703...
# 86 outliers removed for station 1704...
# 88 outliers removed for station 1705...
# 106 outliers removed for station 1706...
# 62 outliers removed for station 1707...
# 77 outliers removed for station 1708...
# 68 outliers removed for station 1709...
# 77 outliers removed for station 1710...
# 115 outliers removed for station 1711...
# 30 outliers removed for station 1712...
# 86 outliers removed for station 1713...
# 55 outliers removed for station 1714...
# 65 outliers removed for station 1715...
# 106 outliers removed for station 1716...
# 73 outliers removed for station 1717...
# 38 outliers removed for station 1718...
# 25 outliers removed for station 1719...
# 72 outliers removed for station 1720...
# 54 outliers removed for station 1721...
# 68 outliers removed for station 1722...
# 116 outliers removed for station 1723...
# 72 outliers removed for station 1724...
# 44 outliers removed for station 1725...
# 61 outliers removed for station 1726...
# 59 outliers removed for station 1727...
# 154 outliers removed for station 1728...
# 149 outliers removed for station 1729...
# 114 outliers removed for station 1730...
# 116 outliers removed for station 1731...
# 62 outliers removed for station 1732...
# 105 outliers removed for station 1733...
# 113 outliers removed for station 1734...
# 60 outliers removed for station 1735...
# 125 outliers removed for station 1736...
# 122 outliers removed for station 1737...
# 138 outliers removed for station 1738...
# 83 outliers removed for station 1739...
# 94 outliers removed for station 1740...
# 43 outliers removed for station 1741...
# 152 outliers removed for station 1742...
# 56 outliers removed for station 1743...
# 70 outliers removed for station 1744...
# 47 outliers removed for station 1745...
# 69 outliers removed for station 1746...
# 91 outliers removed for station 1747...
# 80 outliers removed for station 1748...
# 67 outliers removed for station 1749...
# 91 outliers removed for station 1750...
# 56 outliers removed for station 1751...
# 79 outliers removed for station 1752...
# 60 outliers removed for station 1753...
# 52 outliers removed for station 1754...
# 182 outliers removed for station 1755...
# 76 outliers removed for station 1757...
# 53 outliers removed for station 1758...
# 82 outliers removed for station 1778...
# 61 outliers removed for station 1779...
# 88 outliers removed for station 1781...
# 47 outliers removed for station 1782...
# 53 outliers removed for station 1783...
# 43 outliers removed for station 1784...
# 57 outliers removed for station 1785...
# 47 outliers removed for station 1787...
# 54 outliers removed for station 1789...
# 108 outliers removed for station 1791...
# 63 outliers removed for station 1795...
# 90 outliers removed for station 1798...
# 40 outliers removed for station 1800...
# 64 outliers removed for station 1801...
# 68 outliers removed for station 1802...
# 58 outliers removed for station 1803...
# 62 outliers removed for station 1804...
# 57 outliers removed for station 1806...
# 55 outliers removed for station 1807...
# 15 outliers removed for station 1808...
# 48 outliers removed for station 1809...
# 76 outliers removed for station 1817...
# 86 outliers removed for station 1818...
# 131 outliers removed for station 1819...
# 20 outliers removed for station 1820...
# 38 outliers removed for station 1821...
# 38 outliers removed for station 1822...
# 76 outliers removed for station 1824...
# 54 outliers removed for station 1828...
# 66 outliers removed for station 1834...
# 39 outliers removed for station 1849...
# 44 outliers removed for station 1850...
# 44 outliers removed for station 1851...
# 49 outliers removed for station 1853...
# 57 outliers removed for station 1854...
# 65 outliers removed for station 1860...
# 69 outliers removed for station 1861...
# 26 outliers removed for station 1871...
# 49 outliers removed for station 1873...
# 57 outliers removed for station 1875...
# 38 outliers removed for station 1876...
# 33 outliers removed for station 1877...
# 39 outliers removed for station 1878...
# 69 outliers removed for station 1879...
# 69 outliers removed for station 1880...
# 80 outliers removed for station 1881...
# 61 outliers removed for station 1885...
# 51 outliers removed for station 1889...
# 65 outliers removed for station 1890...
# 30 outliers removed for station 1891...

# %%
set_plt_style('double tex')

thresholds = np.round(np.arange(1.0, 5.01, 0.05), 2)
ax = plt.gca()

_ = plt.violinplot([data_wo_outliers[f"{t}xmip"].values for t in thresholds],
                   positions=thresholds, 
                   showextrema=False,
                   widths=0.05,
                   showmeans=True)

rates = np.array([data_wo_outliers[f"{t}xmip"].mean() for t in thresholds])
sigma_sys = np.array([data_wo_outliers[f"{t}xmip"].std() for t in thresholds])
sigma_stat = np.sqrt(rates)
sigma = np.sqrt(sigma_sys ** 2 + sigma_stat ** 2)

# error = ax.twinx()
ax.plot(thresholds, sigma_stat, label=r"$\sigma_\mathrm{stat.}$", c='r', ls='--')
ax.plot(thresholds, sigma_sys, label=r"$\sigma_{\mathrm{sys.}}$", c='b', ls=':')
ax.plot(thresholds, sigma, label=r"$\sqrt{\Sigma_i\,\sigma_i^2}$", c='g', ls='-.')

# ax.plot([], [], label=r"$\sigma_\mathrm{stat.}$")
# ax.plot([], [],label=r"$\sigma_{\mathrm{sys.}}$")
# ax.plot([], [], label=r"$\sqrt{\Sigma_i\,\sigma_i^2}$")
ax.errorbar([],[], [], label='Events', fmt='ko', ls=None, capsize=2)
ax.set_xlabel("Threshold / $I_\mathrm{MIP}$")
ax.set_ylabel("$r^+$ / Hz")
ax.set_ylim(0.4,)
ax.legend(loc='upper right', ncol=2)
# error.set_ylabel(r'$\sigma_{r^+}\,/\,r^+$')
# error.set_ylim(0, 0.5)
ax.set_yscale('log')
# Out:
# 12:50:30 [DBUG] utils.plotting -- (<99999ms) -- font size set to 9.5
# 12:50:30 [DBUG] utils.plotting -- (    +2ms) -- label size set to 13.0
# 12:50:30 [DBUG] utils.plotting -- (    +2ms) -- figure size set to [3.3, 2.5]
# 12:50:30 [DBUG] utils.plotting -- (    +1ms) -- markersize set to 2.0
# 12:50:30 [DBUG] utils.plotting -- (    +1ms) -- usetex set to True

# %%
thresholds, rates = np.loadtxt('/cr/users/filip/Data/SDMonitHistos/mean_rates.txt', unpack=True)
offset = 20

for x in range(offset):
    for i in range(x, len(thresholds) -1, offset):
        print(f"{thresholds[i]:.2f} & ${rates[i]:.2f} \pm {sigma[i]:.2f}$ & ", end='')

    print('\\\\')
# Out:
# 1.00 & $211 \pm 42$ & 2.00 & $37 \pm 10$ & 3.00 & $9 \pm 3$ & 4.00 & $3 \pm 2$ & \\
# 1.05 & $196 \pm 40$ & 2.05 & $34 \pm 9$ & 3.05 & $8 \pm 3$ & 4.05 & $3 \pm 2$ & \\
# 1.10 & $182 \pm 37$ & 2.10 & $31 \pm 8$ & 3.10 & $8 \pm 3$ & 4.10 & $3 \pm 2$ & \\
# 1.15 & $168 \pm 35$ & 2.15 & $29 \pm 8$ & 3.15 & $7 \pm 3$ & 4.15 & $3 \pm 2$ & \\
# 1.20 & $154 \pm 32$ & 2.20 & $27 \pm 7$ & 3.20 & $7 \pm 3$ & 4.20 & $2 \pm 2$ & \\
# 1.25 & $142 \pm 30$ & 2.25 & $25 \pm 7$ & 3.25 & $6 \pm 3$ & 4.25 & $2 \pm 2$ & \\
# 1.30 & $130 \pm 28$ & 2.30 & $23 \pm 7$ & 3.30 & $6 \pm 3$ & 4.30 & $2 \pm 1$ & \\
# 1.35 & $119 \pm 26$ & 2.35 & $21 \pm 6$ & 3.35 & $6 \pm 3$ & 4.35 & $2 \pm 1$ & \\
# 1.40 & $108 \pm 24$ & 2.40 & $20 \pm 6$ & 3.40 & $5 \pm 3$ & 4.40 & $2 \pm 1$ & \\
# 1.45 & $99 \pm 22$ & 2.45 & $18 \pm 6$ & 3.45 & $5 \pm 2$ & 4.45 & $2 \pm 1$ & \\
# 1.50 & $90 \pm 20$ & 2.50 & $17 \pm 5$ & 3.50 & $5 \pm 2$ & 4.50 & $2 \pm 1$ & \\
# 1.55 & $82 \pm 19$ & 2.55 & $16 \pm 5$ & 3.55 & $5 \pm 2$ & 4.55 & $2 \pm 1$ & \\
# 1.60 & $75 \pm 17$ & 2.60 & $15 \pm 5$ & 3.60 & $4 \pm 2$ & 4.60 & $2 \pm 1$ & \\
# 1.65 & $68 \pm 16$ & 2.65 & $14 \pm 5$ & 3.65 & $4 \pm 2$ & 4.65 & $2 \pm 1$ & \\
# 1.70 & $63 \pm 15$ & 2.70 & $13 \pm 4$ & 3.70 & $4 \pm 2$ & 4.70 & $2 \pm 1$ & \\
# 1.75 & $57 \pm 14$ & 2.75 & $12 \pm 4$ & 3.75 & $4 \pm 2$ & 4.75 & $2 \pm 1$ & \\
# 1.80 & $52 \pm 13$ & 2.80 & $11 \pm 4$ & 3.80 & $4 \pm 2$ & 4.80 & $2 \pm 1$ & \\
# 1.85 & $48 \pm 12$ & 2.85 & $10 \pm 4$ & 3.85 & $3 \pm 2$ & 4.85 & $1 \pm 1$ & \\
# 1.90 & $44 \pm 11$ & 2.90 & $10 \pm 4$ & 3.90 & $3 \pm 2$ & 4.90 & $1 \pm 1$ & \\
# 1.95 & $40 \pm 10$ & 2.95 & $9 \pm 4$ & 3.95 & $3 \pm 2$ & 4.95 & $1 \pm 1$ & \\

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("/cr/tempdata01/filip/UubRandoms/Nov2022/converted/SvenjaFiltered/randoms0009_WCD.dat")
data = np.split(data, len(data) / 3)

for i in [136, 178, 313, 1116, 2477, 2523, 3001, 3227, 4655, 4689, 2217, 2370, 3836, 4142]:
    plt.figure()
    plt.plot(range(2048), data[i][0])
    plt.plot(range(2048), data[i][1])
    plt.plot(range(2048), data[i][2])

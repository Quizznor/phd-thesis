# %%
import matplotlib.pyplot as plt
import numpy as np

file=f"/cr/tempdata01/filip/SSDCalib/RadioCut/randoms0800_SSD.dat"
SSD = np.loadtxt(file)
print(SSD.shape)


for trace in SSD:
    trace = trace[1:] - trace[0]
    break

plt.plot(range(1024), trace)

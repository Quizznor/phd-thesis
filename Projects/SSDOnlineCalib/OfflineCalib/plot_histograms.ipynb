# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # All files, no radio cut

# %%
all_rates = np.zeros(350)

for file in os.listdir("/cr/tempdata01/filip/SSDCalib/T1Rates/Raw"):
    all_rates += np.loadtxt("/cr/data01/filip/SSDT1Rates/" + file)

plt.plot(range(350), all_rates)
plt.yscale("log")

# %% [markdown]
# # All files, radio cut

# %%
all_rates = np.zeros(350)

for file in os.listdir("/cr/tempdata01/filip/SSDCalib/T1Rates/RadioCut"):
    try:
        all_rates += np.loadtxt("/cr/tempdata01/filip/SSDCalib/T1Rates/RadioCut/" + file)
    except FileNotFoundError: pass

plt.plot(range(350), all_rates)
plt.yscale("log")

# %%
from utils.binaries import *
from utils.plotting import *
from utils.Auger.SD import *
# Out:
# 16:57:23 (   +2.9s) [INFO   ] -- import logging
# 16:57:23 (  +218ms) [INFO   ] -- import numpy as np
# 16:57:23 (   +11ms) [INFO   ] -- import uncertainties
# 16:57:24 (  +770ms) [INFO   ] -- import pandas as pd
# 16:57:24 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 16:57:24 (    +3ms) [INFO   ] -- import binaries.tools as tools
# 16:57:24 (  +597ms) [INFO   ] -- import matplotlib.pyplot as plt
# 16:57:25 (  +924ms) [INFO   ] -- import seaborn as so
# 16:57:25 (    +2ms) [INFO   ] -- import plotting.tools as plot
# 16:57:25 (   +22ms) [DEBUG  ] -- font size set to 9.5
# 16:57:25 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 16:57:25 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 16:57:25 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 16:57:25 (    +0ms) [DEBUG  ] -- usetex set to False
# 16:57:25 (   +47ms) [INFO   ] -- set MONI_PATH = '/cr/work/filip/monit_and_sd/'
# ...

# %%
monit = Monit(2025,1,7)
monit.keys()
# Out:
# 16:57:26 (  +283ms) [INFO   ] -- received 1 file(s) as input
# 16:57:26 (  +147ms) [INFO   ] -- View monit keys with self.keys()
# {
#   "TObject": {
#     "fUniqueID": "TObject/fUniqueID",
#     "fBits": "TObject/fBits"
#   },
#   "fLsId": "fLsId",
#   "fTime": "fTime",
#   "fCDASTime": "fCDASTime",
#   "fMonitoring": {
#     "fIsMonitoring": "fMonitoring/fMonitoring.fIsMonitoring",
#     "fIsUUB": "fMonitoring/fMonitoring.fIsUUB",
#     "fPMV": "fMonitoring/fMonitoring.fPMV[3]",
#     "fPMI": "fMonitoring/fMonitoring.fPMI[3]",
#     "fPMT": "fMonitoring/fMonitoring.fPMT[3]",
#     "fElectT": "fMonitoring/fMonitoring.fElectT",
#     "fBatteryT[2]": "fMonitoring/fMonitoring.fBatteryT[2]",
#     "fBatteryV[2]": "fMonitoring/fMonitoring.fBatteryV[2]",
#     "fCurrentLoad": "fMonitoring/fMonitoring.fCurrentLoad",
#     "fSolarPanelV": "fMonitoring/fMonitoring.fSolarPanelV",
#     "fSolarPanelI": "fMonitoring/fMonitoring.fSolarPanelI",
# ...

# %%
time = monit('fLsId')
# Out:
# 16:57:26 (  +380ms) [INFO   ] -- found 621 entries for key fLsId

# %%
import uproot

file = uproot.open('/cr/work/filip/monit_and_sd/2025/01/mc_2025_01_07_18h37.root')

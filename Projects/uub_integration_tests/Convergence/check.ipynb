# %%
from utils.binaries import *
from utils.plotting import *
# Out:
# 09:18:44 ( +154.0s) [INFO   ] -- import logging
# 09:18:44 (    +2ms) [INFO   ] -- import numpy as np
# 09:18:44 (    +2ms) [INFO   ] -- import numpy as np
# 09:18:44 (   +10ms) [INFO   ] -- import uncertainties
# 09:18:44 (  +185ms) [INFO   ] -- import pandas as pd
# 09:18:44 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 09:18:44 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 09:18:44 (  +274ms) [INFO   ] -- import matplotlib.pyplot as plt
# 09:18:45 (  +383ms) [INFO   ] -- import seaborn as so
# 09:18:45 (    +2ms) [INFO   ] -- import plotting.tools as plot
# 09:18:45 (    +7ms) [DEBUG  ] -- font size set to 9.5
# 09:18:45 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 09:18:45 (    +1ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 09:18:45 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 09:18:45 (    +0ms) [DEBUG  ] -- usetex set to False

# %%
t, wcd1, hz1, wcd2, hz2, wcd3, hz3, ssd, hz4 = np.loadtxt(
    "/cr/data01/filip/Data/daqIntegrationTests/v16/calib.test", unpack=True
)
nan_mask = np.isnan(t)

t[nan_mask] = np.interp(
    np.flatnonzero(nan_mask), np.flatnonzero(~nan_mask), t[~nan_mask]
)
muonfill = lambda x: x[~nan_mask]
xb = lambda x: x[nan_mask]

ssd /= 2.64 * 10
wcd1[nan_mask] /= 1.75
wcd2[nan_mask] /= 1.75
wcd3[nan_mask] /= 1.75
wcd1[~nan_mask] /= 10
wcd2[~nan_mask] /= 10
wcd3[~nan_mask] /= 10
t = (t - t[0]) / 3600

start, stop, skip = 0, -1, 1

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
# ax1.plot(xb(t)[start:stop:skip], xb(wcd1)[start:stop:skip], label="WCD 1", ls='--', c='r')
# ax1.plot(xb(t)[start:stop:skip], xb(wcd2)[start:stop:skip], label="WCD 2", ls='--', c='b')
# ax1.plot(xb(t)[start:stop:skip], xb(wcd3)[start:stop:skip], label="WCD 3", ls='--', c='mediumturquoise')

ax1.plot(
    muonfill(t)[start:stop:skip],
    muonfill(wcd1)[start:stop:skip],
    ls="solid",
    c="r",
    label="WCD 1",
)
ax1.plot(
    muonfill(t)[start:stop:skip],
    muonfill(wcd2)[start:stop:skip],
    ls="solid",
    c="b",
    label="WCD 2",
)
ax1.plot(
    muonfill(t)[start:stop:skip],
    muonfill(wcd3)[start:stop:skip],
    ls="solid",
    c="mediumturquoise",
    label="WCD 3",
)
ax1.plot(
    muonfill(t)[start:stop:skip],
    10 * muonfill(ssd)[start:stop:skip],
    label=r"10$\,\times\,$SSD",
    c="k",
)

ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz1)[start:stop:skip], c="r")
ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz2)[start:stop:skip], c="b")
ax2.plot(
    muonfill(t)[start:stop:skip], muonfill(hz3)[start:stop:skip], c="mediumturquoise"
)
ax2.plot(muonfill(t)[start:stop:skip], muonfill(hz4)[start:stop:skip], c="k")

ax2.axhline(70, ls="--", lw=0.8, c="gray")
ax1.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=4)
ax1.set_ylabel("$I_\mathrm{Rate}\,/\,\mathrm{ADC}$")
ax2.set_ylabel("$\mathrm{T}70\,/\,\mathrm{Hz}$")
ax2.set_xlabel("time after DAQ start / h")
# ax2.set_ylim(30, 180)
# Out:
# Text(0.5, 0, 'time after DAQ start / h')

# %%
_ = plt.hist(
    muonfill(hz1), range=(40, 100), bins=30, histtype="step", color="r", label=rf"WCD 1"
)
_ = plt.hist(
    muonfill(hz2), range=(40, 100), bins=30, histtype="step", color="b", label="WCD 2"
)
_ = plt.hist(
    muonfill(hz3),
    range=(40, 100),
    bins=30,
    histtype="step",
    color="mediumturquoise",
    label="WCD 3",
)
_ = plt.hist(
    muonfill(hz4), range=(40, 100), bins=30, histtype="step", color="k", label="SSD"
)

plt.legend()
plt.ylabel("# of occurrences")
plt.xlabel("T70 / Hz")
# Out:
# Text(0.5, 0, 'T70 / Hz')

# %%
r1 = xb(wcd1)[::9] / muonfill(wcd1)[::10]
r2 = xb(wcd2)[::9] / muonfill(wcd2)[::10]
r3 = xb(wcd3)[::9] / muonfill(wcd3)[::10]

plt.scatter(xb(t)[::9], r1, c="r")
plt.scatter(xb(t)[::9], r2, c="b")
plt.scatter(muonfill(t)[::10], r3, c="mediumturquoise")

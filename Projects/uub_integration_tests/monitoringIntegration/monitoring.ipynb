# %%
import uproot

# %%
data = uproot.open('/home/filip/Desktop/didi-synvc/mc_2024_11_16_17h25.root')

# %%
for key in data['SDMonCal'].keys():
    print(key)
# Out:
# SDMonCalBranch
# SDMonCalBranch/TObject
# SDMonCalBranch/TObject/fUniqueID
# SDMonCalBranch/TObject/fBits
# SDMonCalBranch/fLsId
# SDMonCalBranch/fTime
# SDMonCalBranch/fCDASTime
# SDMonCalBranch/fMonitoring
# SDMonCalBranch/fMonitoring/fMonitoring.fIsMonitoring
# SDMonCalBranch/fMonitoring/fMonitoring.fIsUUB
# SDMonCalBranch/fMonitoring/fMonitoring.fPMV[3]
# SDMonCalBranch/fMonitoring/fMonitoring.fPMI[3]
# SDMonCalBranch/fMonitoring/fMonitoring.fPMT[3]
# SDMonCalBranch/fMonitoring/fMonitoring.fElectT
# SDMonCalBranch/fMonitoring/fMonitoring.fBatteryT[2]
# SDMonCalBranch/fMonitoring/fMonitoring.fBatteryV[2]
# SDMonCalBranch/fMonitoring/fMonitoring.fCurrentLoad
# SDMonCalBranch/fMonitoring/fMonitoring.fSolarPanelV
# SDMonCalBranch/fMonitoring/fMonitoring.fSolarPanelI
# SDMonCalBranch/fMonitoring/fMonitoring.fWaterLevel
# SDMonCalBranch/fMonitoring/fMonitoring.fWaterT
# SDMonCalBranch/fMonitoring/fMonitoring.f12VRadio
# SDMonCalBranch/fMonitoring/fMonitoring.f3V
# ...

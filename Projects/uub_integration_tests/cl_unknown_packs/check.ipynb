# %%
from bin import read_package
import struct

# %%
with open('monit_2025_02_18.packs.nobackup', 'rb') as f:
    test = read_package(f)

# %%
packages = []

with open('sd_2025_02_18.packs.nobackup', 'rb') as f:
    while f.read(8) == b"!!_T3_!!":
        packages.append(read_package(f))

# %%
for pack in packages:
    print(pack)
# Out:
# {'0': {'station': 954, 'type': 9, 'version': 1, 'size': 44, 'data': b'\x00\x00\x01\t\x00\x00\x01\x11\x00\x00\x01\x17\x00\x00\x011\x00\x00@\x1f\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01'}, '1': {'station': 954, 'type': 3, 'version': 2, 'size': 4520, 'data': b'T\xdfZOT\xdfZ\x8c\x00\x01\x00\x03\x00\n\x00\x0f\x00\x15\x00G\x00N\x00C\x00;\x00Z\x00D\x00@\x004\x007\x00,\x00&\x00&\x00/\x00\x1c\x00/\x00\x1e\x00*\x00\x10\x00\x15\x00 \x00$\x00"\x00\x16\x00$\x00\x1c\x00\x1e\x00-\x00\x19\x00\x1a\x00%\x00,\x00 \x007\x00+\x00-\x00\x1e\x00$\x00/\x006\x004\x001\x00&\x00:\x00.\x00+\x002\x003\x00+\x00:\x00:\x00:\x00.\x002\x00L\x00.\x007\x00A\x004\x009\x00<\x006\x009\x00>\x00:\x000\x008\x00@\x00(\x004\x00?\x00<\x00:\x00.\x008\x00>\x00.\x005\x003\x003\x002\x00D\x00D\x009\x009\x00<\x009\x00H\x00=\x009\x000\x00F\x00;\x00E\x00>\x000\x00A\x004\x00B\x00C\x00N\x008\x00B\x007\x00G\x000\x008\x00D\x00G\x00>\x00M\x00>\x00O\x00A\x00B\x00B\x00F\x00A\x00L\x00N\x00J
# ...

# %%
pack = packages[1]['0']

print(struct.unpack('d', pack['data']))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[33], line 3
#       1 pack = packages[1]['0']
# ----> 3 print(struct.unpack('d', pack['data']))
#
# error: unpack requires a buffer of 8 bytes

# %%
from utils.Auger.SD import Monit
from utils.plotting import *
from utils.binaries import *
# Out:
# 16:33:46 (   +2.4s) [INFO   ] -- import logging
# 16:33:46 (   +80ms) [INFO   ] -- import numpy as np
# 16:33:46 (    +7ms) [INFO   ] -- import uncertainties
# 16:33:46 (  +166ms) [INFO   ] -- import pandas as pd
# 16:33:46 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 16:33:46 (    +1ms) [INFO   ] -- import binaries.tools as tools
# 16:33:46 (    +1ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 16:33:46 (    +0ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 16:33:46 (    +1ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 16:33:46 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 16:33:46 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# 16:33:46 (    +1ms) [INFO   ] -- set OFLN_PATH = PosixPath('/home/filip/Public/offline/install')
# 16:33:46 (  +285ms) [INFO   ] -- import matplotlib.pyplot as plt
# 16:33:47 (  +375ms) [INFO   ] -- import seaborn as so
# 16:33:47 (    +1ms) [INFO   ] -- import plotting.tools as plot
# 16:33:47 (    +4ms) [DEBUG  ] -- font size set to 9.5
# 16:33:47 (    +1ms) [DEBUG  ] -- label size set to 13.0
# 16:33:47 (    +0ms) [DEBUG  ] -- figure size set to [6.6, 3.3]
# 16:33:47 (    +1ms) [DEBUG  ] -- markersize set to 2.0
# 16:33:47 (    +0ms) [DEBUG  ] -- usetex set to False

# %%
# t_sd, st, mip = np.loadtxt('out.txt', unpack=True)
monit = Monit.Monit(2025, 2, range(6, 11))
# Out:
# 16:33:48 (  +879ms) [INFO   ] -- received 5 file(s) as input
# 16:33:48 (  +251ms) [INFO   ] -- View monit keys with self.keys()

# %%
fig, axes = plt.subplots(4, 1, sharex=True)

for station, ax in zip([943, 944, 949, 954], axes):
    t = monit('fTime', station)
    mmip = monit('fPeak[4]', station)

    # mask = station == st
    # ax.scatter(plot.to_datetime(t_sd[mask]), mip[mask]/100)
    ax.plot(plot.to_datetime(t), mmip, marker='none')


plot.apply_datetime_format(ax)
# Out:
# 16:34:22 (  +22.4s) [INFO   ] -- found 983 entries for key fTime and station #943
# 16:34:22 (   +15ms) [INFO   ] -- found 983 entries for key fPeak[4] and station #943
# 16:34:22 (   +36ms) [INFO   ] -- found 983 entries for key fTime and station #944
# 16:34:22 (   +14ms) [INFO   ] -- found 983 entries for key fPeak[4] and station #944
# 16:34:22 (   +53ms) [INFO   ] -- found 983 entries for key fTime and station #949
# 16:34:22 (   +14ms) [INFO   ] -- found 983 entries for key fPeak[4] and station #949
# 16:34:22 (   +36ms) [INFO   ] -- found 985 entries for key fTime and station #954
# 16:34:22 (   +13ms) [INFO   ] -- found 985 entries for key fPeak[4] and station #954

# %%
mip.shape

# %%
# monit.keys()
t = monit('fTime', 945)
r = monit('f70HzRate[4]', 945)

plt.plot(t, r)

# %%
print(r[:, -1])

# %%
from utils.auger.SD.monit import Monit
from utils.binaries import *
from utils.plotting import *
# Out:
# 19:48:42 (   +3.1s) [INFO   ] -- import logging
# 19:48:43 (   +89ms) [INFO   ] -- import numpy as np
# 19:48:43 (    +5ms) [INFO   ] -- import uncertainties
# 19:48:43 (  +161ms) [INFO   ] -- import pandas as pd
# 19:48:43 (    +1ms) [WARNING] -- pandas support to be dropped at some point!
# 19:48:43 (    +0ms) [INFO   ] -- import binaries.tools as tools
# 19:48:43 (    +1ms) [INFO   ] -- set MONI_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 19:48:43 (    +1ms) [INFO   ] -- set HIST_PATH = PosixPath('/home/filip/Data/monit_and_sd')
# 19:48:43 (    +0ms) [INFO   ] -- set PLOT_PATH = PosixPath('/home/filip/Data/plots')
# 19:48:43 (    +0ms) [INFO   ] -- set DATA_PATH = PosixPath('/home/filip/Data')
# 19:48:43 (    +0ms) [INFO   ] -- set SCAN_PATH = PosixPath('/home/filip/Public/xy-calibration')
# 19:48:43 (    +1ms) [INFO   ] -- set OFLN_PATH = PosixPath('/home/filip/Public/offline/install')
# 19:48:43 (  +286ms) [INFO   ] -- import matplotlib.pyplot as plt
# ...

# %%
test = Monit(2025, 2, range(10, 12))

station = 954

time = test('fTime', station)
mip = test('fPeak', station)
rate = test('f70HzRate', station)
# Out:
# (0) ALL FILES BELOW
# (1) mc_2025_02_10_00h01.root
# (2) mc_2025_02_10_20h39.root
# 19:48:56 (  +10.7s) [INFO   ] -- received 2 file(s) as input
# 19:48:57 (  +132ms) [INFO   ] -- View monit keys with self.keys()
# 19:48:57 (    +4ms) [INFO   ] -- found 156 entries for key fTime and station #954
# 19:48:57 (    +5ms) [INFO   ] -- found 156 entries for key fPeak and station #954
# 19:48:57 (   +10ms) [INFO   ] -- found 156 entries for key f70HzRate and station #954

# %%
# ax1 = plt.gca()
# ax2 = ax1.twinx()
# ax3 = ax1.twinx()

# ax1.plot(time, mip, ls='-', marker='none')
# ax2.plot(time, rate, ls='--', marker='none')

fig, axes = plt.subplots(4, 1, sharex=True)
for i, ax in enumerate(axes):
    ax.hist(rate[:, i], histtype='step', label=f'PMT #{i+1}', bins=20)
    ax.set_yticks([],[])
    ax.legend()

#     ax3.plot([], [], label=f'PMT #{i}', marker='none')

# ax3.set_yticks([], [])
# ax3.legend(ncol=2)

# %%
test.keys()
# Out:
# {
#   "TObject": {
#     "fUniqueID": "TObject/fUniqueID",
#     "fBits": "TObject/fBits"
#   },
#   "fLsId": "fLsId",
#   "fTime": "fTime",
#   "fCDASTime": "fCDASTime",
#   "fMonitoring": {
#     "fIsMonitoring": "fMonitoring/fMonitoring.fIsMonitoring",
#     "fIsUUB": "fMonitoring/fMonitoring.fIsUUB",
#     "fPMV": "fMonitoring/fMonitoring.fPMV[3]",
#     "fPMI": "fMonitoring/fMonitoring.fPMI[3]",
#     "fPMT": "fMonitoring/fMonitoring.fPMT[3]",
#     "fElectT": "fMonitoring/fMonitoring.fElectT",
#     "fBatteryT": "fMonitoring/fMonitoring.fBatteryT[2]",
#     "fBatteryV": "fMonitoring/fMonitoring.fBatteryV[2]",
#     "fCurrentLoad": "fMonitoring/fMonitoring.fCurrentLoad",
#     "fSolarPanelV": "fMonitoring/fMonitoring.fSolarPanelV",
#     "fSolarPanelI": "fMonitoring/fMonitoring.fSolarPanelI",
#     "fWaterLevel": "fMonitoring/fMonitoring.fWaterLevel",
#     "fWaterT": "fMonitoring/fMonitoring.fWaterT",
#     "f12VRadio": "fMonitoring/fMonitoring.f12VRadio",
# ...
